# %% [markdown]
# # framework imports and install

# %%
# !pip install transformers==4.10.2
# !pip install sentencepiece==0.1.96
# !pip install rouge
# !pip install langid
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers==4.10.2 in /usr/local/lib/python3.7/dist-packages (4.10.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (1.21.6)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.9.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (2022.6.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.2) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.10.2) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.10.2) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece==0.1.96 in /usr/local/lib/python3.7/dist-packages (0.1.96)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rouge in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: langid in /usr/local/lib/python3.7/dist-packages (1.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from langid) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (3.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.1.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface_hub) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (2.10)

# %%
import pandas as pd
import requests
import json
import operator
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForSequenceClassification
from tqdm import tqdm
from huggingface_hub import notebook_login
from tqdm import tqdm

# %%
dir = '/content/drive/MyDrive/working_directory/tfm/data'
hoaxdf = pd.read_excel(dir+'/Cancer_en.xlsx')

# %%
hoaxdf
# Out:
#               Fact checker, institution  \
# 0                            PolitiFact
# 1                            PolitiFact
# 2                            PolitiFact
# 3                            PolitiFact
# 4                            PolitiFact
# 5                            PolitiFact
# 6                            PolitiFact
# 7                            PolitiFact
# 8                            PolitiFact
# 9                            PolitiFact
# 10                        Factcheck.org
# 11                             FullFact
# 12                             FullFact
# 13                             FullFact
# 14  Cancer Treatment Centers of America
# 15  Cancer Treatment Centers of America
# 16  Cancer Treatment Centers of America
# 17  Cancer Treatment Centers of America
# 18  Cancer Treatment Centers of America
# 19  Cancer Treatment Centers of America
# 20  Cancer Treatment Centers of America
# 21  Cancer Treatment Centers of America
# 22  Cancer Treatment Centers of America
# 23  Cancer Treatment Centers of America
# 24                   Cancer Research UK
# 25                   Cancer Research UK
# 26                   Cancer Research UK
# 27                   Cancer Research UK
# 28                   Cancer Research UK
# 29                   Cancer Research UK
# 30                   Cancer Research UK
# 31                   Cancer Research UK
# 32                   Cancer Research UK
# 33                   Medical News Today
# 34                   Medical News Today
# 35                   Medical News Today
# 36                   Medical News Today
# 37                   Medical News Today
# 38                   Medical News Today
# 39                   Medical News Today
# 40                   Medical News Today
# 41                   Medical News Today
# 42                   Medical News Today
# 43                   Medical News Today
# 44                   Medical News Today
# 45                   Medical News Today
# 46                   Medical News Today
# 47                   Medical News Today
# 48                   Medical News Today
# 49                   Medical News Today
# 50                   Medical News Today
# 51                   Medical News Today
#
#                               Normalized Hoax-checked  \
# 0   huge spike in soft-tissue cancers diagnoses in...
# 1   Cancer institute finally admits marijuana kill...
# 2   No one has died of cancer or heart disease sin...
# 3   80% of children born in developing countries d...
# 4   Cutting out sugar and drinking hot lemon water...
# 5      Abortion increases the risk of breast cancer.
# 6          The flu shot is designed to spread cancer.
# 7   Dandelion root is able to kill 98% of cancer c...
# 8   A molecule found in a Himalayan fungus kills c...
# 9   Cancer and matters to do with kidney failure k...
# 10                         Polio vaccine cause cancer
# 11  Rubbing hydrogen peroxide over your body every...
# 12                Antiperspirant causes breast cancer
# 13  Having 10 or more sexual partners increases ca...
# 14               Getting a biopsy makes cancer spread
# 15                 Eating sugar causes cancer to grow
# 16       You won’t need surgery if the tumor is solid
# 17                         Skin cancer is color blind
# 18           Chemotherapy always has bad side effects
# 19      A lump in your breast is always breast cancer
# 20          Pregnant women can’t get cancer treatment
# 21       Hair will never grow back after chemotherapy
# 22                       Cancer will always come back
# 23  Oncologists don’t want patients trying unusual...
# 24                                Phones cause cancer
# 25                   Eating burnt foods cause cancer
# 26        Plastic bottles and containers cause cancer
# 27                 Artificial sweeteners cause cancer
# 28            Genetically modified foods cause cancer
# 29  Eating foods grown on farms that use pesticide...
# 30             Use toiletries and makeup cause cancer
# 31               Milk and dairy products cause cancer
# 32                                Stress cause cancer
# 33                           Power lines cause cancer
# 34             Cancer surgery causes cancer to spread
# 35                 Wearing a bra causes breast cancer
# 36                   Herbal medicines can cure cancer
# 37                        There is no cure for cancer
# 38                   Only smokers develop lung cancer
# 39     There is no way to reduce the lung cancer risk
# 40               nly older adults develop lung cancer
# 41  Living in a polluted city is worse than smokin...
# 42  Breathing in talcum powder increases lung canc...
# 43                  Lung cancer always shows symptoms
# 44                     Lung cancer is always terminal
# 45  Antioxidant supplements protect against lung c...
# 46  In vitro fertilization increases the risk of b...
# 47         Breast cancer only happens to older adults
# 48       Nipple piercings increase breast cancer risk
# 49                       Men do not get breast cancer
# 50           Mammograms cause breast cancer to spread
# 51                 Root canal procedures cause cancer
#
#      Original hoax Text from source or article tittle
# 0   Soft-tissue cancer diagnoses have “climbed thr...
# 1   "Cancer institute finally admits marijuana kil...
# 2   “No one has died of cancer or heart disease si...
# 3   "80% of children born in developing countries ...
# 4   Says cutting out sugar and drinking hot lemon ...
# 5   Says abortion increases the risk of breast can...
# 6       The flu shot is "designed to spread cancer."
# 7   "Dandelion root is able to kill 98% of cancer ...
# 8   A molecule found in a Himalayan fungus "kills ...
# 9   "Cancer and matters to do with kidney failure ...
# 10                Did the Polio Vaccine Cause Cancer?
# 11  Rubbing hydrogen peroxide over your body every...
# 12  The role of antiperspirant in causing breast c...
# 13  Women who have had 10 or more sexual partners ...
# 14               Getting a biopsy makes cancer spread
# 15                 Eating sugar causes cancer to grow
# 16       You won’t need surgery if the tumor is solid
# 17                         Skin cancer is color blind
# 18           Chemotherapy always has bad side effects
# 19      A lump in your breast is always breast cancer
# 20          Pregnant women can’t get cancer treatment
# 21       Hair will never grow back after chemotherapy
# 22                       Cancer will always come back
# 23  Oncologists don’t want patients trying unusual...
# 24                     Do mobile phones cause cancer?
# 25              Can eating burnt foods cause cancer?
# 26  Does using plastic bottles and containers caus...
# 27             Do artificial sweeteners cause cancer?
# 28        Do genetically modified foods cause cancer?
# 29         Can pesticides or herbicides cause cancer?
# 30                           Cosmetics and toiletries
# 31          Can milk and dairy products cause cancer?
# 32                           Can stress cause cancer?
# 33                           Power lines cause cancer
# 34             Cancer surgery causes cancer to spread
# 35                 Wearing a bra causes breast cancer
# 36                   Herbal medicines can cure cancer
# 37                        There is no cure for cancer
# 38                   Only smokers develop lung cancer
# 39     There is no way to reduce the lung cancer risk
# 40               nly older adults develop lung cancer
# 41  Living in a polluted city is worse than smokin...
# 42  Breathing in talcum powder increases lung canc...
# 43        If I had lung cancer, I would have symptoms
# 44                     Lung cancer is always terminal
# 45  Antioxidant supplements protect against lung c...
# 46            IVF increases the risk of breast cancer
# 47         Breast cancer only happens to older adults
# 48       Nipple piercings increase breast cancer risk
# 49                       Men do not get breast cancer
# 50           Mammograms cause breast cancer to spread
# 51        Root canals and cancer: Debunking the myths

# %% [markdown]
# # Defining filters

# %% [markdown]
# ## Semantic filters

# %% [markdown]
# ### Entailment filter

# %%
def xnli_response(reference,candidate_list,threshold):

    all_alignments = []
    all_align_scores = []
    all_align_texts = []


    entailment_request_2 = {'queried_text': reference,
                  'comparison_text': candidate_list,
                  'th': threshold}
    ent_output =requests.get('private_request', json=entailment_request_2).json()
    ent_scores = list(zip(ent_output["contradiction_p"],
    ent_output["entailment_p"], ent_output["neutral_p"]))

    #the indices sort the previous index of the values by entailment. 
    #We can get the previous order by using the numbers of the indices
    ent_result = sorted(list(zip(ent_output["entailment"], ent_scores, ent_output["texts"], ent_output["indices"])), key = operator.itemgetter(3))
    
    all_alignments.extend(zipped[0] for zipped in ent_result)
    all_align_scores.extend(zipped[1] for zipped in ent_result)
    all_align_texts.extend(zipped[2] for zipped in ent_result)
        
    return all_alignments, all_align_scores, all_align_texts

# %%
def semantic_filter(reference,candidate_list, threshold=None):
  filtered_phrases = []
  scores =[]
  results = xnli_response(reference,candidate_list,threshold)
  for idx,result in enumerate(results[0]):
    if result == 'Entailment':
      filtered_phrases.append(results[2][idx])
      scores.append(results[1][idx])
  return filtered_phrases, scores

# %% [markdown]
# ## Lexical filters

# %%
def rouge_score(candidate,reference,ngram=1 ,metric='f'):
  from rouge import Rouge
  rouge = Rouge()

  if ngram == 1:
    ngram = 'rouge-1'
  elif ngram == 2:
    ngram = 'rouge-2'
  elif ngram == 'l':
    ngram = 'rouge-l'

  all_scores = rouge.get_scores(candidate.lower(), reference.lower())
  
  return all_scores[0][ngram][metric]

# %%
def bleu_score(candidate, reference, ngram=1):
  from nltk.translate.bleu_score import sentence_bleu

  if ngram == 1:
    ngram = (1,0,0,0)
  if ngram == 2:
    ngram = (0,1,0,0)
  if ngram == 3:
    ngram = (0,0,1,0)
  if ngram == 4:
    ngram = (0,0,0,1)
  
  candidate = nltk.word_tokenize(candidate.lower())
  reference = nltk.word_tokenize(reference.lower())
  
  return sentence_bleu([reference], candidate, weights=ngram)

# %%
def jaccard_similarity(candidate, reference, ngram=1):
  import nltk
  nltk.download('punkt', quiet=True)

  candidate = nltk.word_tokenize(candidate.lower())
  reference = nltk.word_tokenize(reference.lower())

  if ngram != 1:
    candidate = nltk.ngrams(candidate, n=ngram)
    reference = nltk.ngrams(reference, n=ngram)

  candidate = set(candidate)
  reference = set(reference)
  intersection = len(list(candidate.intersection(reference)))
  union = (len(candidate) + len(reference)) - intersection
  
  return float(intersection) / union

# %%
def lexical_score(candidate, reference, method='rouge', ngram = 1, **kwargs):
  dispatcher={'rouge':rouge_score, 'bleu':bleu_score , 'jaccard':jaccard_similarity}
  try:
      get_score=dispatcher[method]
  except KeyError:
      raise ValueError('invalid input')
  lexical_score = get_score(candidate,reference,ngram, **kwargs)
  return lexical_score

# %% [markdown]
# # Filter pipeline

# %%
import torch
torch.cuda.empty_cache()

# %%
class paraphraser():
  phrase='' # here is saved the last phase used in paraphrases generation
  paraphrases=[] # here is saved the most recent paraphrased batch generated

  def __init__(self, paraphrase_model="ramsrigouthamg/t5-large-paraphraser-diverse-high-quality"):
    import pandas as pd
    import requests
    import json
    import operator
    import numpy as np
    from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
    from tqdm import tqdm
    
    self.paraphrase_model = paraphrase_model
    #load model
    self.model = AutoModelForSeq2SeqLM.from_pretrained(paraphrase_model)
    self.tokenizer = AutoTokenizer.from_pretrained(paraphrase_model)

  def generate(self, phrase, num_return_sequences=50):
    import torch

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    self.model = self.model.to(device)
    #generate with T5 Large
    if self.paraphrase_model == "ramsrigouthamg/t5-large-paraphraser-diverse-high-quality":
      self.phrase = phrase
      text = "paraphrase: "+ phrase + " </s>"

      encoding = self.tokenizer.encode_plus(text,max_length = 128, padding=True, return_tensors="pt")
      input_ids,attention_mask  = encoding["input_ids"].to(device), encoding["attention_mask"].to(device)

      self.model.eval()
      beam_outputs = self.model.generate(  #temperature=1,  top_k = 50, top_p = 0.95, repetition_penalty=1.5
      input_ids=input_ids,attention_mask=attention_mask,
      max_length=128,
      early_stopping=True,
      num_beams=num_return_sequences,
      num_return_sequences=num_return_sequences,
      top_p=0.95,
      repetition_penalty = 1.5)
  
      self.paraphrases = []
      for beam_output in beam_outputs:
        sent = self.tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)[19:]
        self.paraphrases.append(sent)
      return self.paraphrases

    #generate with Pegasus
    if self.paraphrase_model ==  'tuner007/pegasus_paraphrase':
      text = phrase
      encoding =  self.tokenizer(text, max_length=128, padding=True, return_tensors='pt')
      input_ids,attention_mask  = encoding["input_ids"].to(device), encoding["attention_mask"].to(device)

      self.model.eval()
      beam_outputs = self.model.generate( #temperature=1.5, tok_k=50, top_p=1.0, repetition_penalty=1.0
      input_ids=input_ids,attention_mask=attention_mask,
      max_length=128,
      early_stopping=True,
      num_beams=num_return_sequences,
      num_return_sequences=num_return_sequences,
      temperature=1.5)

      self.paraphrases = []
      for beam_output in beam_outputs:
        sent = self.tokenizer.decode(beam_output, skip_special_tokens=True)
        self.paraphrases.append(sent)
      return self.paraphrases
   
  def filter(self, reference=None,paraphrases = None, lexical_filter= 'rouge', ngram=1 , semantic_threshold=None, lexical_threshold=None, top_return='All', get_score=False, **kwargs):
      if reference == None:
        reference = self.phrase
      if paraphrases == None:
        paraphrases = self.paraphrases

      #semantic filter
      paraphrases_filtered = paraphrases
      #paraphrases_filtered = semantic_filter(reference,paraphrases,threshold=semantic_threshold)[0]
      #lexical filter
      if len(paraphrases_filtered) == 0:
        return [] 
      
      if lexical_threshold == None:
        lexical_threshold = 1
      
      scored = []
      for candidate in paraphrases_filtered:
        score = lexical_score(candidate=candidate, reference=reference, method=lexical_filter, ngram=ngram, **kwargs)
        if score < lexical_threshold:
          scored.append((candidate,score))
      scored.sort(key=lambda x:x[1])

      if top_return == 'All' or top_return > len(scored):
        print(len(scored))
        top_return = len(scored)
      
      if get_score:
        return scored[top_return]
      else:
        candidates = [ candidate[0] for candidate in scored]
        return candidates[:top_return]

# %% [markdown]
# # Running filter pipeline(T5-large / Rouge-1 / Entailment)

# %%
t5 = paraphraser()

# %% [markdown]
# ##Testing with first hoax

# %%
hoaxdf['Normalized Hoax-checked'][0]
# Out:
# 'huge spike in soft-tissue cancers diagnoses in 2021 as a result of COVID-19 vaccines'

# %%
t5.generate(hoaxdf['Normalized Hoax-checked'][0])
# Out:
# ['In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a huge rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a dramatic rise in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a large rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a major rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a significant rise in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a huge rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a drastic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a big rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of the COVID-19 vaccines, there was a huge rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a large rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccinations, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a big increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of the COVID-19 vaccines, there was a large rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a significant rise in soft tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccinations, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a large increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a big jump in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a major rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnosis as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there has been a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a major rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a dramatic rise in soft tissue cancer diagnoses in 2021.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a major increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of the COVID-19 vaccines, there was a significant rise in soft tissue cancer diagnoses in 2021.',
#  'In 2021, there was a massive rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a huge increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnosis as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a big rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a surge in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a surge in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'As a result of the COVID-19 vaccines, there was a dramatic rise in soft tissue cancer diagnoses in 2021.',
#  'In 2021, there was a significant increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.']

# %%
filtered_sorted = t5.filter()

# %%
filtered_sorted
# Out:
# ['As a result of the COVID-19 vaccines, there was a significant rise in soft tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a dramatic rise in soft tissue cancer diagnoses in 2021.',
#  'In 2021, there was a dramatic rise in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a significant rise in soft tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a dramatic rise in soft tissue cancer diagnoses in 2021.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnosis as a result of COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnosis as a result of COVID-19 vaccines.',
#  'In 2021, there was a surge in soft tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccinations.',
#  'As a result of the COVID-19 vaccines, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'As a result of the COVID-19 vaccines, there was a large rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there has been a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a major rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a dramatic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a significant rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a large rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a major rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of the COVID-19 vaccines, there was a rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a drastic rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a big rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a large rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccinations, there was a significant rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a big increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccinations, there was a dramatic rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a large increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a big jump in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a major rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of the COVID-19 vaccines.',
#  'In 2021, there was a major increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a massive rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a big rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a significant increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a surge in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'In 2021, there was a rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a rise in soft-tissue cancer diagnoses in 2021.',
#  'As a result of COVID-19 vaccines, there was a surge in soft-tissue cancer diagnoses in 2021.',
#  'As a result of the COVID-19 vaccines, there was a huge rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a huge rise in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.',
#  'As a result of COVID-19 vaccines, there was a huge rise in soft-tissue cancer diagnoses in 2021.',
#  'In 2021, there was a huge increase in soft-tissue cancer diagnoses as a result of COVID-19 vaccines.']

# %% [markdown]
# ## Paraphrasing hoaxes

# %%
t5 = paraphraser()

# %%
filtered_sorted_top_paraphrases = []
for n in tqdm(range(len(hoaxdf['Normalized Hoax-checked']))):
  t5.generate(hoaxdf['Normalized Hoax-checked'][n],num_return_sequences=50)
  filtered_sorted = t5.filter(lexical_filter= 'rouge', ngram=1 , semantic_threshold=None, lexical_threshold=None, top_return='All')
  filtered_sorted_top30_paraphrases.append(filtered_sorted)
# Out:
#   2%|▏         | 1/52 [00:01<01:12,  1.42s/it]
# 50
#   4%|▍         | 2/52 [00:02<00:50,  1.00s/it]
# 50
#   6%|▌         | 3/52 [00:03<00:49,  1.01s/it]
# 50
#   8%|▊         | 4/52 [00:03<00:44,  1.07it/s]
# 50
#  10%|▉         | 5/52 [00:04<00:42,  1.12it/s]
# 50
#  12%|█▏        | 6/52 [00:05<00:37,  1.23it/s]
# 50
#  13%|█▎        | 7/52 [00:06<00:34,  1.32it/s]
# 50
#  15%|█▌        | 8/52 [00:07<00:35,  1.23it/s]
# 50
#  17%|█▋        | 9/52 [00:08<00:40,  1.06it/s]
# 50
#  19%|█▉        | 10/52 [00:09<00:49,  1.19s/it]
# 50
#  21%|██        | 11/52 [00:10<00:41,  1.02s/it]
# 50
#  23%|██▎       | 12/52 [00:11<00:40,  1.00s/it]
# 50
#  25%|██▌       | 13/52 [00:12<00:34,  1.12it/s]
# 50
#  27%|██▋       | 14/52 [00:13<00:35,  1.06it/s]
# 50
#  29%|██▉       | 15/52 [00:13<00:31,  1.19it/s]
# 50
#  31%|███       | 16/52 [00:14<00:28,  1.27it/s]
# 50
#  33%|███▎      | 17/52 [00:15<00:27,  1.28it/s]
# 50
#  35%|███▍      | 18/52 [00:16<00:27,  1.22it/s]
# 50
#  37%|███▋      | 19/52 [00:16<00:26,  1.25it/s]
# 50
#  38%|███▊      | 20/52 [00:17<00:24,  1.28it/s]
# 50
#  40%|████      | 21/52 [00:18<00:23,  1.33it/s]
# 50
#  42%|████▏     | 22/52 [00:19<00:21,  1.41it/s]
# 50
#  44%|████▍     | 23/52 [00:19<00:19,  1.52it/s]
# 50
#  46%|████▌     | 24/52 [00:20<00:19,  1.44it/s]
# 50
#  48%|████▊     | 25/52 [00:20<00:17,  1.57it/s]
# 50
#  50%|█████     | 26/52 [00:21<00:16,  1.59it/s]
# 50
#  52%|█████▏    | 27/52 [00:22<00:15,  1.61it/s]
# 50
#  54%|█████▍    | 28/52 [00:22<00:14,  1.67it/s]
# 50
#  56%|█████▌    | 29/52 [00:23<00:14,  1.64it/s]
# 50
#  58%|█████▊    | 30/52 [00:24<00:16,  1.35it/s]
# 50
#  60%|█████▉    | 31/52 [00:24<00:14,  1.41it/s]
# 50
#  62%|██████▏   | 32/52 [00:25<00:13,  1.45it/s]
# 50
#  63%|██████▎   | 33/52 [00:26<00:12,  1.57it/s]
# 50
#  65%|██████▌   | 34/52 [00:26<00:10,  1.68it/s]
# 50
#  67%|██████▋   | 35/52 [00:27<00:10,  1.67it/s]
# 50
#  69%|██████▉   | 36/52 [00:27<00:09,  1.63it/s]
# 50
#  71%|███████   | 37/52 [00:28<00:08,  1.67it/s]
# 50
#  73%|███████▎  | 38/52 [00:29<00:08,  1.64it/s]
# 50
#  75%|███████▌  | 39/52 [00:29<00:07,  1.64it/s]
# 50
#  77%|███████▋  | 40/52 [00:30<00:07,  1.53it/s]
# 50
#  79%|███████▉  | 41/52 [00:30<00:07,  1.57it/s]
# 50
#  81%|████████  | 42/52 [00:31<00:07,  1.42it/s]
# 50
#  83%|████████▎ | 43/52 [00:32<00:06,  1.32it/s]
# 50
#  85%|████████▍ | 44/52 [00:33<00:05,  1.36it/s]
# 50
#  87%|████████▋ | 45/52 [00:33<00:04,  1.47it/s]
# 50
#  88%|████████▊ | 46/52 [00:34<00:04,  1.47it/s]
# 50
#  90%|█████████ | 47/52 [00:35<00:03,  1.40it/s]
# 50
#  92%|█████████▏| 48/52 [00:36<00:02,  1.48it/s]
# 50
#  94%|█████████▍| 49/52 [00:36<00:02,  1.37it/s]
# 50
#  96%|█████████▌| 50/52 [00:37<00:01,  1.47it/s]
# 50
#  98%|█████████▊| 51/52 [00:38<00:00,  1.39it/s]
# 50
# 100%|██████████| 52/52 [00:38<00:00,  1.34it/s]
# 50

# %%
hoaxdf['filtered_sorted_topparaphrases'] = filtered_sorted_top_paraphrases

# %% [markdown]
# #Generating keyword queries with querie generator(Private tool)

# %%
from query_builder_v3_1 import get_kw_comb_v2

# %%
query_builder_paraphrases_filtered = [] 
for n in tqdm(range(len(hoaxdf['filtered_sorted_top30_paraphrases']))):
  query_builder_paraphrases = []
  paraphrases_list = hoaxdf['filtered_sorted_top_paraphrases'][n]
  for paraphrase in paraphrases_list:
    statement = get_kw_comb_v2(statement_text=paraphrase , 
                              language_code="en", # <-- Important
                              lemmatized=False, 
                              level = 0, # <- keywords per combination =  n - level
                              top_n = 7, 
                              diversity = 0.2, 
                              max_query_len = 1024
                              )[0]
    if isinstance(statement, list):
      statement = statement[0]
    query_builder_paraphrases.append(statement)                       
  query_builder_paraphrases_filtered.append(query_builder_paraphrases)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   6%|▌         | 3/52 [00:44<11:51, 14.52s/it]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   8%|▊         | 4/52 [00:56<10:52, 13.59s/it]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  10%|▉         | 5/52 [01:10<10:52, 13.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  12%|█▏        | 6/52 [01:27<11:24, 14.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# ...
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  98%|█████████▊| 51/52 [10:58<00:11, 11.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# 100%|██████████| 52/52 [11:09<00:00, 12.87s/it]

# %%
query_builder_paraphrases_filtered
# Out:
# [['(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#   '(((2021 OR 2.021)) rise diagnoses cancer vaccinations covid-19)',
#   '(((2021 OR 2.021)) rise significant cancer vaccinations covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer diagnosis covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer diagnosis covid-19)',
#   '(((2021 OR 2.021)) cancer tissue vaccines surge soft covid-19)',
#   '(((2021 OR 2.021)) diagnoses cancer surge vaccinations covid-19)',
#   '(((2021 OR 2.021)) rise diagnoses cancer vaccinations covid-19)',
#   '(((2021 OR 2.021)) rise vaccines significant cancer covid-19)',
#   '(((2021 OR 2.021)) diagnoses vaccines cancer rise covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer large covid-19)',
#   '(((2021 OR 2.021)) rise vaccines significant cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines major cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines significant cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines major cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines drastic cancer covid-19)',
#   '(((2021 OR 2.021)) rise big cancer vaccines covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer large covid-19)',
#   '(((2021 OR 2.021)) rise significant cancer vaccinations covid-19)',
#   '(((2021 OR 2.021)) vaccines big cancer increase covid-19)',
#   '(((2021 OR 2.021)) rise diagnoses cancer vaccinations covid-19)',
#   '(((2021 OR 2.021)) diagnoses vaccines cancer surge covid-19)',
#   '(((2021 OR 2.021)) vaccines cancer increase large covid-19)',
#   '(((2021 OR 2.021)) vaccines big cancer jump covid-19)',
#   '(((2021 OR 2.021)) rise vaccines major cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) vaccines major increase cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines massive cancer covid-19)',
#   '(((2021 OR 2.021)) rise big cancer vaccines covid-19)',
#   '(((2021 OR 2.021)) diagnoses vaccines cancer increase covid-19)',
#   '(((2021 OR 2.021)) diagnoses vaccines cancer surge covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) rise vaccines diagnoses cancer covid-19)',
#   '(((2021 OR 2.021)) diagnoses vaccines cancer surge covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer huge covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer huge covid-19)',
#   '(((2021 OR 2.021)) rise vaccines cancer huge covid-19)',
#   '(((2021 OR 2.021)) vaccines cancer increase huge covid-19)'],
#  ['(cancer research (cause OR confirmed) marijuana)',
#   '(cannabis cancer research (confirmed OR caused) marijuana)',
#   '(cancer smoking research (confirmed OR caused) marijuana)',
#   '(cancer research (confirmed OR caused) marijuana)',
#   '(marijuana center cancer smoking (admitted OR causes))',
#   '(cancer center (confirmed OR cause) marijuana)',
#   '(finally cigarettes cancer smoking center (admitted OR causes))',
#   '(cancer center (admitted OR cause) marijuana)',
#   '(marijuana cancer center (confirmed OR causes))',
#   '(marijuana cancer center (admitted OR causes))',
#   '(marijuana cancer center (accepted OR causes))',
#   '(marijuana cancer research (confirmed OR causes))',
#   '(recently marijuana cancer center (accepted OR causes))',
#   '(recently marijuana cancer center (confirmed OR causes))',
#   '(marijuana cancer research (accepted OR causes))',
#   '(marijuana officially cancer center (confirmed OR causes))',
#   '(also marijuana cancer center (accepted OR causes))',
#   '(marijuana cancer center (acknowledged OR causes))',
#   '(recently marijuana cancer center (reported OR causes))',
#   '(marijuana officially cancer center (accepted OR causes))',
#   '(marijuana cancer center (confirmed OR causes))',
#   '(finally responsible cancer marijuana center admitted)',
#   '(finally cancer smoking marijuana center (admitted OR causes))',
#   '(cancer finally center (admitted OR cause) marijuana)',
#   '(marijuana center cancer smoking (admitted OR kills))',
#   '(marijuana cancer finally center (accepted OR cause))',
#   '(marijuana finally cancer fact center (causes OR accepted))',
#   '(finally marijuana cancer center (admitted OR causes))',
#   '(marijuana cancer finally center (accepted OR causes))',
#   '(marijuana cancer center (confirmed OR kills))',
#   '(marijuana cancer finally center (acknowledged OR causes))',
#   '(marijuana cancer finally research (accepted OR causes))',
#   '(institute marijuana cancer (confirmed OR causes))',
#   '(marijuana cancer center (admitted OR kills))',
#   '(institute marijuana cancer (accepted OR causes))',
#   '(recently marijuana cancer center (confirmed OR kills))',
#   '(marijuana cancer research (confirmed OR kills))',
#   '(institute marijuana cancer (admitted OR causes))',
#   '(marijuana cancer finally research (acknowledged OR causes))',
#   '(charity marijuana cancer finally (accepted OR causes))',
#   '(marijuana cancer center (confirmed OR kills))',
#   '(finally cancer smoking marijuana center (admitted OR kills))',
#   '(finally marijuana cancer center (admitted OR kills))',
#   '(institute marijuana cancer finally (accepted OR causes))',
#   '(finally institute marijuana cancer (admitted OR causes))',
#   '(marijuana cancer finally center (accepted OR kills))',
#   '(marijuana cancer finally center (acknowledged OR kills))',
#   '(institute marijuana cancer (confirmed OR kills))',
#   '(institute marijuana cancer finally (acknowledged OR causes))',
#   '(marijuana cancer finally center (admits OR causes))'],
#  ['(heart existence since one cancer died covid-19)',
#   '(one first cancer heart (died OR introduced) covid-19)',
#   '(since one cancer heart (died OR introduced) covid-19)',
#   '(since one cancer heart (died OR launched) covid-19)',
#   '(one project cancer heart (died OR launched) covid-19)',
#   '(one program heart cancer (died OR launched) covid-19)',
#   '(since one cancer heart (died OR started) covid-19)',
#   '(since lung one heart (died OR introduced) covid-19)',
#   '(one program heart cancer (died OR introduced) covid-19)',
#   '(since lung one heart (died OR launched) covid-19)',
#   '(since one cancer heart (died OR invented) covid-19)',
#   '(lung one disease heart (died OR started) covid-19)',
#   '(since one cancer heart (died OR established) covid-19)',
#   '(since one cancer heart (died OR born) covid-19)',
#   '(one project cancer heart (died OR established) covid-19)',
#   '(one project cancer heart (died OR started) covid-19)',
#   '(one program heart cancer (died OR started) covid-19)',
#   '(since one breast heart (introduced OR died) covid-19)',
#   '(one program heart cancer (began OR died) covid-19)',
#   '(disease cancer heart epidemic (began OR died) covid-19)',
#   '(one project cancer heart (began OR died) covid-19)',
#   '(one disease cancer heart (began OR died) covid-19)',
#   '(since one cancer heart (began OR died) covid-19)',
#   '(one campaign heart cancer (began OR died) covid-19)',
#   '(one phenomenon cancer heart (began OR died) covid-19)',
#   '(disease cancer heart epidemic (began OR died) covid-19)',
#   '(one cancer heart event (began OR died) covid-19)',
#   '(since one disease heart (died OR introduced) covid-19)',
#   '(one first cancer heart (died OR introduced) covid-19)',
#   '(heart existence since one cancer died covid-19)',
#   '(one first cancer heart (died OR established) covid-19)',
#   '(heart since one disease cancer died covid-19)',
#   '(since one cancer heart (died OR introduced) covid-19)',
#   '(since one cancer heart (died OR launched) covid-19)',
#   '(since one cancer heart (died OR started) covid-19)',
#   '(since one cancer heart (died OR invented) covid-19)',
#   '(since one cancer heart (died OR born) covid-19)',
#   '(since one cancer heart (died OR established) covid-19)',
#   '(since one cancer heart (died OR initiated) covid-19)',
#   '(since one cancer heart (died OR founded) covid-19)',
#   '(since one cancer heart (died OR introduced) covid-19)',
#   '(since one cancer heart (died OR launched) covid-19)',
#   '(since one cancer heart (died OR started) covid-19)',
#   '(since one cancer heart (died OR announced) covid-19)',
#   '(since one cancer heart (died OR started) covid-19)',
#   '(heart since one cancer active died covid-19)',
#   '(since one cancer heart (began OR died) covid-19)',
#   '(since one cancer heart (started OR died) covid-19)',
#   '(heart since one disease cancer died covid-19)',
#   '(since one cancer heart (began OR died) covid-19)'],
#  ['((("eighty" OR 80)) percent nations cancer year children die)',
#   '((("eighty" OR 80)) countries percent cancer year children die)',
#   '((("eighty" OR 80)) percent cancer industrial children (die OR born))',
#   '((("eighty" OR 80)) countries percent cancer year children die)',
#   '((("eighty" OR 80)) percent nations cancer year children die)',
#   '((80%) nations every cancer year children die)',
#   '((("eighty" OR 80)) percent countries cancer children (die OR born))',
#   '((("eighty" OR 80)) percent countries cancer children (die OR born))',
#   '((("eighty" OR 80)) countries percent cancer year children die)',
#   '((("eighty" OR 80)) percent cancer industrial children (die OR born))',
#   '((80%) year countries cancer children (die OR estimated))',
#   '((80%) countries every cancer year children die)',
#   '((("eighty" OR 80)) countries percent cancer year children die)',
#   '((80%) countries every cancer year children die)',
#   '((80%) countries cancer industrial children (die OR born))',
#   '((80%) poor countries cancer children (die OR born))',
#   '((80%) countries every cancer year children die)',
#   '((80%) countries every cancer year children die)',
#   '((80%) countries every cancer year children die)',
#   '((80%) countries every cancer year children die)',
#   '((("eighty" OR 80)) percent countries cancer children (die OR born))',
#   '((80%) countries every cancer year children die)',
#   '((80%) year cancer children nations (die OR developing))',
#   '((("eighty" OR 80)) percent countries cancer children (die OR born))',
#   '((80%) year countries cancer children (die OR born))',
#   '((80%) year countries cancer children (die OR born))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) countries cancer industrial children (die OR born))',
#   '((80%) poor countries cancer children (die OR born))',
#   '((80%) cancer children nations (die OR born OR developing))',
#   '((80%) year countries cancer children (die OR developing))',
#   '((80%) year cancer children nations (developing OR die))',
#   '((80%) countries cancer children (live OR developing OR die))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) countries cancer industrial children (born OR die))',
#   '((80%) poor countries cancer children (born OR die))',
#   '((80%) year countries cancer children (die OR born))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) cancer children nations (born OR developing OR die))',
#   '((80%) countries cancer children (born OR emerging OR die))',
#   '((80%) countries cancer children (born OR developing OR die))',
#   '((80%) countries cancer industrial children (born OR die))',
#   '((80%) countries cancer children (die OR born OR developing))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) year countries cancer children (developing OR die))',
#   '((80%) countries cancer children (born OR developing OR die))',
#   '((80%) countries cancer children (born OR developing OR die))',
#   '((80%) countries cancer children (born OR developing OR die))',
#   '((80%) countries cancer children (born OR developing OR die))'],
#  ['(hot water diet cancer lemon change reversed)',
#   '(intake juice sugar cancer lemon (reducing OR drinking))',
#   '(intake juice sugar cancer lemon (lowering OR drinking))',
#   '(hot water sugar cancer lemon (reducing OR reversed))',
#   '(hot water sugar cancer lemon (reducing OR sipping))',
#   '(hot water sugar cancer lemon (lowering OR reversed))',
#   '(hot water sugar cancer lemon (lowering OR sipping))',
#   '(hot water sugar cancer lemon (removing OR reversed))',
#   '(hot water sugar cancer lemon (prevent OR drink))',
#   '(intake water sugar cancer lemon (reducing OR drinking))',
#   '(intake water sugar cancer lemon (lowering OR drinking))',
#   '(hot juice sugar cancer lemon (reversed OR sipping))',
#   '(hot juice sugar cancer lemon (reversed OR consuming))',
#   '(hot water sugar cancer lemon (reducing OR drinking))',
#   '(hot water sugar cancer lemon (removing OR drinking))',
#   '(hot water sugar cancer lemon (lowering OR drinking))',
#   '(hot water sugar cancer lemon (reducing OR drinking))',
#   '(hot water sugar cancer lemon (reversed OR drinking))',
#   '(hot water sugar cancer lemon (treated OR drinking))',
#   '(hot water sugar cancer lemon (reversed OR drinking))',
#   '(hot water sugar cancer lemon (treated OR drinking))',
#   '(hot water sugar cancer lemon (treated OR drinking))',
#   '(hot water sugar cancer lemon (prevented OR drinking))',
#   '(hot water sugar cancer lemon (reduced OR drink))',
#   '(hot water sugar cancer lemon (reversed OR enjoying))',
#   '(hot water sugar cancer lemon (reversed OR sipping))',
#   '(hot water sugar cancer lemon (treated OR enjoying))',
#   '(hot water sugar cancer lemon (reversed OR consuming))',
#   '(sugar water tumors lemon (cutting OR prevented OR drinking))',
#   '(hot water sugar cancer lemon (cutting OR prevented))',
#   '(hot water sugar cancer lemon (cutting OR reduced))',
#   '(hot water sugar cancer lemon (treated OR sipping))',
#   '(hot water sugar cancer lemon (prevented OR sipping))',
#   '(hot juice sugar cancer lemon (reversed OR drinking))',
#   '(hot water sugar cancer lemon (prevent OR drinking))',
#   '(hot water sugar cancer lemon (drinking OR reversed))',
#   '(hot water sugar cancer lemon (fight OR drinking))',
#   '(hot water sugar cancer lemon (treat OR drinking))',
#   '(hot water sugar cancer lemon (reversed OR drinking))',
#   '(hot water sugar cancer lemon (reversed OR drinking))',
#   '(hot water sugar cancer lemon (treated OR drinking))',
#   '(hot water sugar cancer lemon (prevented OR drinking))',
#   '(hot water sugar cancer lemon (reduced OR drinking))',
#   '(hot water sugar cancer lemon (alleviated OR drinking))',
#   '(hot water sugar cancer lemon (cured OR drinking))',
#   '(hot water sugar cancer lemon (cutting OR reversed))',
#   '(hot water sugar cancer lemon (cure OR drinking))',
#   '(hot water sugar cancer lemon (reversed OR drinking))',
#   '(sugar water cancer lemon (cutting OR reduced OR drinking))',
#   '(hot water sugar cancer lemon (treated OR drinking))'],
#  ['(hand abortions cancer breast prevention goes)',
#   '(risks pregnancy result breast cancer raised)',
#   '(risks pregnancy result cancer breast rises)',
#   '(risks pregnancy result cancer breast rise)',
#   '(abortions result breast cancer)',
#   '(pregnancy breast cancer result)',
#   '(abortion also breast cancer increased)',
#   '(risk pregnancy cancer breast rises)',
#   '(abortion breast cancer linked)',
#   '(risk abortions cancer breast rises)',
#   '(risk childbirth cancer breast rises)',
#   '(risk pregnancy result cancer breast goes)',
#   '(risks abortion result breast cancer raised)',
#   '(risks abortion result cancer breast elevated)',
#   '(risk pregnancy result cancer breast raised)',
#   '(risk pregnancy result cancer breast rises)',
#   '(risks abortion result cancer breast rises)',
#   '(risks abortion result cancer breast rise)',
#   '(risk pregnancy result cancer breast rises)',
#   '(abortion risk cancer breast (goes OR performed))',
#   '(risk result cancer breast fertility rises)',
#   '(birth risk result cancer breast rises)',
#   '(breastfeeding risk result cancer breast rises)',
#   '(abortion risk cancer breast also increased)',
#   '(abortion risk cancer breast (rises OR performed))',
#   '(abortion risk cancer breast also raised)',
#   '(abortion risk cancer breast also elevated)',
#   '(abortion risk breast cancer also increased)',
#   '(abortion result breast cancer)',
#   '(abortion risk breast cancer goes)',
#   '(abortion risk cancer breast elevated)',
#   '(abortion risk breast cancer raised)',
#   '(abortion risk result cancer breast goes)',
#   '(abortion risk result breast cancer raised)',
#   '(abortion risk result cancer breast elevated)',
#   '(abortion risk result cancer breast increased)',
#   '(abortion risk breast cancer rises)',
#   '(abortion risk breast cancer rises)',
#   '(increases pregnancy cancer breast risk)',
#   '(abortion risk result cancer breast rises)',
#   '(abortion risk result cancer breast rises)',
#   '(increases pregnancy result cancer breast risk)',
#   '(risk abortions cancer breast rises)',
#   '(abortion risk breast cancer rises)',
#   '(increases result cancer breast abortion risk)',
#   '(increases breast cancer abortion risk)',
#   '(abortion risk cancer breast also raises)',
#   '(abortion risk cancer breast rises)',
#   '(abortion risk breast cancer raises)',
#   '(abortion risk breast cancer increases)'],
#  ['(humans disease flu shot (supposed OR cause))',
#   '(people disease flu shot (supposed OR cause))',
#   '(formation flu tumor shot (supposed OR cause))',
#   '(lung disease flu shot (supposed OR cause))',
#   '(flu disease cancerous shot (supposed OR cause))',
#   '(disease flu shot (supposed OR cause))',
#   '(vaccine flu cancer (supposed OR cause))',
#   '(flu cancerous shot (supposed OR cause))',
#   '(humans cancer shot flu (supposed OR cause))',
#   '(people cancer shot flu (supposed OR cause))',
#   '(flu cancer shot children (supposed OR cause))',
#   '(lung flu cancer shot (supposed OR cause))',
#   '(flu cancer shot (intended OR cause))',
#   '(flu cancer shot (shown OR spread))',
#   '(flu cancer shot (supposed OR help))',
#   '(flu cancer shot (supposed OR cause))',
#   '(flu cancer shot (intended OR cause))',
#   '(flu cancer shot (meant OR cause))',
#   '(disease flu shot (supposed OR spread))',
#   '(flu cancer shot (expected OR cause))',
#   '(flu cancer shot (supposed OR promote))',
#   '(flu cancer shot (believed OR cause))',
#   '(disease flu shot (intended OR spread))',
#   '(flu cancer shot (intended OR promote))',
#   '(flu cancer shot (supposed OR kill))',
#   '(flu cancer shot (supposed OR pass))',
#   '(flu cancer shot (suppose OR cause))',
#   '(disease flu shot (designed OR cause))',
#   '(flu cancer shot (supposed OR carry))',
#   '(flu cancer shot (supposed OR spread))',
#   '(flu cancer shot (believed OR spread))',
#   '(flu cancer shot (intended OR spread))',
#   '(flu spread cancer shot (supposed OR cause))',
#   '(flu cancer shot (supposed OR spread))',
#   '(flu specifically cancer shot (designed OR cause))',
#   '(flu cancer shot (designed OR cause))',
#   '(flu cancer shot (supposed OR spread))',
#   '(flu cancer shot (intended OR spread))',
#   '(flu cancer shot (meant OR spread))',
#   '(flu cancer shot (designed OR fight))',
#   '(flu cancer shot (designed OR promote))',
#   '(disease flu shot (designed OR spread))',
#   '(flu cancer shot (designed OR eradicate))',
#   '(flu cancer shot (designed OR combat))',
#   '(flu cancer shot (designed OR prevent))',
#   '(flu cancer shot (designed OR eliminate))',
#   '(flu cancer shot (designed OR kill))',
#   '(flu cancer shot (designed OR spread))',
#   '(flu specifically cancer shot (designed OR spread))',
#   '(flu cancer shot (designed OR spread))'],
#  ['((98%) less dandelion week tumor root destroy)',
#   '((98%) less dandelion week cancer root destroy)',
#   '((98%) less dandelion week cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancerous root destroy)',
#   '((98% OR ("forty-eight" OR 48)) cells dandelion cancer root killed)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root killed)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion tumor root killing)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion tumor root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root cure)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root killed)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root killing)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root killed)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root kill)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root killing)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root killed)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion tumor root destroy)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) cells dandelion cancer root kill)',
#   '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root destroy)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root kill)',
#   '((98% OR ("forty-eight" OR 48)) hours dandelion cancer root kill)'],
#  ['((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency chemical cancer killed)',
#   '((("forty" OR 40)) cells fungus potency chemical cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency cancer substance killed)',
#   '(molecule himalayan cells fungus cancer (isolated OR killed))',
#   '(molecule himalayan cells fungus cancer (discovered OR killed))',
#   '(molecule himalayan cells fungus cancer present killed)',
#   '(himalayan cells fungus chemical cancer (found OR killed))',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency chemical cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency cancer substance killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus chemical potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency cancer substance killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) drug cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus cancer potent killed)',
#   '((("forty" OR 40)) compound cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus cancer molecule (killing OR killed))',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) protein cells fungus potency cancer killed)',
#   '((("forty" OR 40)) cells fungus potency chemical cancer destroyed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '(molecule himalayan cells fungus cancer (found OR killed))',
#   '(molecule himalayan cells fungus cancer (found OR destroyed))',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer destroyed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer destroyed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer die)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer destroys)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer killed)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer destroys)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer kills)',
#   '((("forty" OR 40)) molecule cells fungus potency cancer kills)'],
#  ['(kidney tuberculosis cancer (killed OR aids OR die) kenya)',
#   '(tuberculosis disease cancer malaria kidney die (kenya OR hiv))',
#   '(kidney tuberculosis cancer (aids OR died OR die) kenya)',
#   '(kidney tuberculosis cancer (die OR aids OR died) kenya)',
#   '(kidney tuberculosis cancer (die OR aids OR died) kenya)',
#   '(kidney tuberculosis cancer aids (killed OR die) kenya)',
#   '(tuberculosis malaria cancer kidney aids killed kenya)',
#   '(kidney tuberculosis disease cancer (aids OR die) kenya)',
#   '(kidney tuberculosis disease cancer (aids OR die) kenya)',
#   '(tuberculosis disease cancer malaria kidney die (kenya OR hiv))',
#   '(kidney tuberculosis cancer aids (killed OR die) kenya)',
#   '(kidney tuberculosis disease aids (die OR killed) kenya)',
#   '(kidney tuberculosis disease aids (die OR died) kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(kidney tuberculosis disease aids (die OR died) kenya)',
#   '(kidney tuberculosis cancer aids (died OR die) kenya)',
#   '(kidney tuberculosis cancer aids (die OR died) kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(kidney tuberculosis cancer aids (died OR die) kenya)',
#   '(malaria disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis disease cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids kill kenya)',
#   '(tuberculosis malaria cancer kidney aids kill kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)',
#   '(tuberculosis malaria cancer kidney aids die kenya)'],
#  ['(vaccination result cancer program)',
#   '(vaccination result cancer process)',
#   '(vaccination program cancer linked)',
#   '(vaccination program cancer caused)',
#   '(fluorovirus cancer linked)',
#   '(tumors polio vaccinations linked)',
#   '(poliovaccines cancer caused)',
#   '(vaccines tumors (linked OR polio))',
#   '(fluorovirus cancer caused)',
#   '(poliovirus cancer vaccinations linked)',
#   '(poliovaccines cancer linked)',
#   '(poliovaccination cancer linked)',
#   '(poliovaccines cancer caused)',
#   '(cancer (linked OR poliovaccine))',
#   '(poliovaccination cancer caused)',
#   '(poliovaccine cancer caused)',
#   '(cancer vaccinations linked)',
#   '(result cancer polio vaccinations)',
#   '(vaccines result cancer polio)',
#   '(vaccines cancer polio caused)',
#   '(vaccine flu cancer linked)',
#   '(vaccines cancer polio linked)',
#   '(cancer polio vaccinations linked)',
#   '(vaccines cancer (polio OR linked))',
#   '(cancer polio vaccinations linked)',
#   '(cancer polio vaccinations caused)',
#   '(product cancer polio vaccinations)',
#   '(vaccines cancer breast (polio OR linked))',
#   '(product vaccines cancer polio)',
#   '(vaccine flu cancer caused)',
#   '(vaccines cancer (linked OR polio))',
#   '(cancer polio vaccinations linked)',
#   '(vaccines cancer polio caused)',
#   '(cancer polio vaccinations caused)',
#   '(vaccines cancer polio associated)',
#   '(cancer polio vaccinations associated)',
#   '(vaccines cancer polio linked)',
#   '(responsible vaccines cancer polio)',
#   '(vaccination cancer (linked OR polio))',
#   '(cancer polio vaccinations linked)',
#   '(cause cancer common vaccines polio)',
#   '(vaccine result cancer polio)',
#   '(vaccines cancer polio (shown OR cause))',
#   '(vaccine cancer polio linked)',
#   '(vaccine cancer use (polio OR linked))',
#   '(cause vaccines cancer polio)',
#   '(vaccine cancer polio caused)',
#   '(vaccine cancer polio caused)',
#   '(vaccines cancer polio cause)',
#   '(vaccines cancer polio cause)'],
#  ['(body day every hydrogen solution peroxide raging)',
#   '(day every hydrogen cancer peroxide (raging OR used))',
#   '(body day every hydrogen peroxide (rustling OR applied))',
#   '(day every hydrogen cancer peroxide (used OR raging))',
#   '(body day every hydrogen peroxide (applied OR raging))',
#   '(day every hydrogen cancer peroxide (used OR rustling))',
#   '(day every hydrogen cancer peroxide (used OR rusting))',
#   '(body day every hydrogen peroxide (applied OR rustling))',
#   '(body day every hydrogen peroxide (injected OR raging))',
#   '(body day rusty every hydrogen peroxide injected)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day rusty hydrogen cancer peroxide coating)',
#   '(body day cancer peroxide coating rusting hydrogen)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day hydrogen cancer peroxide (coating OR cure))',
#   '(body day every hydrogen coats peroxide raging)',
#   '(body day every hydrogen peroxide (raging OR coat))',
#   '(body day every hydrogen coats peroxide raging)',
#   '(body day every hydrogen coats peroxide raging)',
#   '(body day every hydrogen coats peroxide rustling)',
#   '(body day every hydrogen peroxide (raging OR reaches))',
#   '(body day every hydrogen coats peroxide rusting)',
#   '(body day every hydrogen peroxide (raging OR reaches))',
#   '(body day blankets every hydrogen peroxide raging)',
#   '(body day every hydrogen peroxide (raging OR sweats))',
#   '(body day every hydrogen peroxide (sweats OR raging))',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day cancer peroxide treatment every hydrogen)',
#   '(body day every hydrogen cancer peroxide coating)',
#   '(body day every hydrogen peroxide vaporizes)',
#   '(body day every hydrogen cancer peroxide causing)',
#   '(body day every hydrogen peroxide rub)',
#   '(body day rusty every hydrogen peroxide sprayed)',
#   '(body day every hydrogen cancer peroxide fighting)',
#   '(body day every hydrogen peroxide rubbed)',
#   '(body day every hydrogen peroxide robbing)',
#   '(body day every hydrogen peroxide rub)',
#   '(body day every hydrogen peroxide raging)',
#   '(body day every hydrogen peroxide raging)',
#   '(body day every hydrogen peroxide spray)',
#   '(body day every hydrogen peroxide rubbed)',
#   '(body day every hydrogen cancer peroxide rubbed)',
#   '(body day every hydrogen cancer peroxide robbing)',
#   '(body day every hydrogen cancer peroxide squeezing)',
#   '(body day every hydrogen cancer peroxide robbing)',
#   '(body day every hydrogen cancer peroxide rubbed)',
#   '(body day every hydrogen cancer peroxide rubbed)'],
#  ['(antiperspirants result breast cancer)',
#   '(antiperspirants breast cancer caused)',
#   '(antiperspirants breast cancer caused)',
#   '(antiperspirants breast cancer linked)',
#   '(antiperspirants breast cancer triggered)',
#   '(antiperspirants breast cancer attributed)',
#   '(antiperspirants breast cancer induced)',
#   '(antiperspirants breast cancer caused)',
#   '(antiperspirants breast cancer associated)',
#   '(antiperspirants breast cancer related)',
#   '(breast antibiotics cancer caused)',
#   '(therapy antiperspirant drug breast cancer caused)',
#   '(antiperspirant result breast cancer)',
#   '(antiperspirant breast cancer caused)',
#   '(antiperspirant drug breast cancer use caused)',
#   '(antiperspirant breast cancer drug caused)',
#   '(breast cancer use product antiperspirant)',
#   '(product antiperspirant cancer breast)',
#   '(therapy cancer breast product antiperspirant)',
#   '(antiperspirant cancer drugs breast caused)',
#   '(result cancer use breast antiperspirant)',
#   '(antiperspirant cancer use breast caused)',
#   '(therapy result cancer breast antiperspirant)',
#   '(antiperspirant cancer drugs breast caused)',
#   '(antiperspirant cancer breast caused)',
#   '(antiperspirant cancer use breast caused)',
#   '(antiperspirant breast cancer use linked)',
#   '(therapy antiperspirant breast cancer caused)',
#   '(antiperspirant breast medications cancer caused)',
#   '(antiperspirant breast cancer agents caused)',
#   '(antiperspirant breast cancer medication caused)',
#   '(antiperspirant cancer drugs breast triggered)',
#   '(antiperspirant breast cancer caused)',
#   '(antiperspirant breast cancer use attributed)',
#   '(therapy antiperspirant breast cancer linked)',
#   '(antiperspirant breast cancer triggered)',
#   '(antiperspirant breast cancer use triggered)',
#   '(antiperspirant cancer drugs breast induced)',
#   '(antiperspirant breast cancer use associated)',
#   '(treatment antiperspirant breast cancer caused)',
#   '(antiperspirant breast cancer use related)',
#   '(antiperspirant cancer drugs breast linked)',
#   '(antiperspirant breast cancer caused)',
#   '(antiperspirant cancer drugs breast caused)',
#   '(hormones antiperspirant breast cancer caused)',
#   '(antiperspirant cancer drugs breast attributed)',
#   '(antiperspirant breast cancer attributed)',
#   '(therapy antiperspirant breast cancer associated)',
#   '(antiperspirant exposure cancer breast caused)',
#   '(antiperspirant breast cancer caused)'],
#  ['(ten sexual risk partners cancer female rises)',
#   '(ten sexual risk partners cancer female raised)',
#   '(((10 OR "ten")) sexual risk partners cancer female rises)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten men sexual cancer partners women risk)',
#   '(ten sexual breast cancer partners women risk)',
#   '(ten sexual women risk partners cancer raises)',
#   '(ten men partners cancer intimate women risk)',
#   '(ten men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(ten men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten sexual women risk partners cancer raises)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten men partners cancer intimate women risk)',
#   '(ten men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten sexual breast cancer partners women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(ten men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual cancer partners women risk)',
#   '(((10 OR "ten")) sexual women risk partners cancer raises)',
#   '(((10 OR "ten")) men cancer partners intimate women risk)',
#   '(ten sexual partners breast cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(ten sexual partners breast cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) sexual cancer breast partners women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(ten men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)',
#   '(((10 OR "ten")) men sexual partners cancer women risk)'],
#  ['(formation biopsy tumor help)',
#   '(biopsy cancer first step spreading)',
#   '(biopsy risk cancer increase)',
#   '(transmission biopsy cancer help)',
#   '(biopsy cancer progression help)',
#   '(biopsy result cancer)',
#   '(risk biopsy cancer help)',
#   '(product biopsy cancer)',
#   '(formation biopsy cancer help)',
#   '(propagation biopsy cancer help)',
#   '(biopsy cancer dissemination help)',
#   '(risk biopsy cancer increases)',
#   '(results biopsy cancer progression receiving)',
#   '(biopsy cancer prevention help)',
#   '(results biopsy cancer (spreading OR receiving))',
#   '(results biopsy cancer progression)',
#   '(biopsy result cancer)',
#   '(results biopsy cancer spreading)',
#   '(results biopsy cancer development)',
#   '(biopsy cancer help)',
#   '(biopsy risk cancer determine)',
#   '(risk results biopsy cancer)',
#   '(spread biopsy cancer aid)',
#   '(biopsy spread cancer help)',
#   '(biopsy cancer (causes OR spread))',
#   '(biopsy spread cancer aids)',
#   '(biopsy cancer (cause OR spread))',
#   '(biopsy spread cancer help)',
#   '(biopsy spread cancer help)',
#   '(biopsy cancer (cause OR spread))',
#   '(biopsy cancer spread)',
#   '(spread results biopsy cancer receiving)',
#   '(biopsy cancer (cause OR spread))',
#   '(biopsy cancer (spread OR help))',
#   '(biopsy spread cancer help)',
#   '(helps biopsy cancer risk getting)',
#   '(risk results biopsy cancer getting)',
#   '(transmission helps biopsy cancer getting)',
#   '(biopsy results spread cancer)',
#   '(biopsy spread cancer helps)',
#   '(biopsy cancer (getting OR spreads))',
#   '(biopsy cancer spread)',
#   '(biopsy cancer (causes OR spread))',
#   '(spread biopsy cancer cause)',
#   '(results biopsy cancer getting)',
#   '(biopsy cancer (getting OR spread))',
#   '(also biopsy cancer (getting OR spread))',
#   '(biopsy cancer (spread OR getting))',
#   '(spread biopsy cancer helps getting)',
#   '(spread results biopsy cancer getting)'],
#  ['(cells sugar diet result cancer increase)',
#   '(sugar diet result cancer rise intake)',
#   '(cells sugar diet result cancer rise)',
#   '(sugar diet result cancer rise)',
#   '(intake sugar result cancer rise)',
#   '(intake cells sugar cancer also affected)',
#   '(sugar diet cancer result intake)',
#   '(sugar diet cancer result)',
#   '(intake sugar result cancer)',
#   '(cells sugar result cancer (eating OR increase))',
#   '(cells sugar result cancer (eating OR rise))',
#   '(rates sugar result cancer (eating OR rise))',
#   '(cells sugar result cancer (eating OR expand))',
#   '(cells sugar result cancer (eating OR develop))',
#   '(cells sugar diet result cancer grow)',
#   '(cells sugar diet result cancer grow)',
#   '(sugar result cancer (eating OR rise))',
#   '(sugar result cancer (eating OR risen))',
#   '(sugar result cancer (eating OR develop))',
#   '(sugar result cancer (eating OR rise))',
#   '(sugar diet cancer result grow)',
#   '(sugar result cancer (rises OR eating))',
#   '(cells sugar cancer also (eating OR affected))',
#   '(cells sugar cancer (grow OR consume))',
#   '(sugar result cancer eating)',
#   '(cells sugar cancer (accelerated OR eating))',
#   '(sugar result cancer eating)',
#   '(cells sugar cancer (eating OR triggered))',
#   '(cells sugar cancer (eating OR increase))',
#   '(sugar cancer (triggered OR eating))',
#   '(sugar cancer (develop OR eating))',
#   '(sugar cancer (rise OR eating))',
#   '(sugar cancer (caused OR eating))',
#   '(cells sugar result cancer (eating OR grow))',
#   '(cells sugar result cancer (eating OR grow))',
#   '(cells sugar likely cancer (develop OR eating))',
#   '(cells sugar likely cancer (develop OR eating))',
#   '(cells sugar prone cancer (growing OR eating))',
#   '(sugar result cancer (eating OR grow))',
#   '(cells sugar prone cancer (increase OR eating))',
#   '(cells sugar prone cancer (increasing OR eating))',
#   '(cells sugar cancer able (expand OR eating))',
#   '(cells sugar prone cancer (rise OR eating))',
#   '(cells sugar cancer able (develop OR eating))',
#   '(cells sugar cancer (eating OR grow))',
#   '(cells sugar cancer (eating OR grow))',
#   '(cells sugar cancer (eating OR grow))',
#   '(cells sugar likely cancer (grow OR eating))',
#   '(sugar cancer (grow OR eating))',
#   '(cells sugar cancer able (grow OR eating))'],
#  ['(surgery tumor solid needing)',
#   '(surgery tumor solid required)',
#   '(surgery tumor solid needing)',
#   '(need surgery tumor solid)',
#   '(need surgery tumor solid)',
#   '(need surgery tumor solid)',
#   '(surgery tumor solid need)',
#   '(surgery tumors solid need)',
#   '(need surgery tumor solid)',
#   '(need surgery tumor solid)',
#   '(need surgery tumor solid)',
#   '(surgery tumor chemotherapy solid require)',
#   '(surgery tumor solid require)',
#   '(surgery tumor solid)',
#   '(surgery tumor solid need)',
#   '(tumour surgery solid need)',
#   '(surgery tumor solid (may OR require))',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid require)',
#   '(surgery tumor solid)',
#   '(surgery tumor solid need)',
#   '(tumour surgery solid need)',
#   '(surgery cancer solid need)',
#   '(surgery tumor solid don)',
#   '(surgery tumor chemotherapy solid need)',
#   '(surgery tumor chemotherapy solid need)',
#   '(solid surgery tumor radiation need)',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid (may OR need))',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid need)',
#   '(clear surgery tumor need)',
#   '(surgery tumor likely solid need)',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid (would OR need))',
#   '(strong surgery tumor need)',
#   '(surgery tumor firm need)',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid need don)',
#   '(clear surgery tumor need)',
#   '(surgery tumor solid need)',
#   '(strong surgery tumor need)',
#   '(surgery tumor firm need)',
#   '(healthy surgery tumor need)',
#   '(surgery tumor stable need)',
#   '(surgery intact tumor need)',
#   '(surgery tumor large need)',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid need)',
#   '(surgery tumor solid need)'],
#  ['(skin disease cancer colorblind)',
#   '(skin phenomenon cancer colorblind)',
#   '(colorblindness cancer skin caused)',
#   '(condition skin cancer colorblind)',
#   '(skin colorblind primarily cancer)',
#   '(skin cancer colorblind mainly)',
#   '(colorblind cancer skin)',
#   '(skin colorblind cancer mostly)',
#   '(skin cancer colorblind also)',
#   '(skin cancer blind color described)',
#   '(skin colorblind cancer)',
#   '(skin cancer)',
#   '(skin cancer blindness color caused)',
#   '(skin cancer blindness color characterized)',
#   '(pigment skin disease cancer blind)',
#   '(skin blind result cancer color going)',
#   '(skin cancer blindness color)',
#   '(skin colour cancer primarily blind)',
#   '(patients skin cancer color blind)',
#   '(skin cancer colour mainly blind)',
#   '(skin cancer blindness color)',
#   '(skin disease cancer color epidemic blind)',
#   '(skin disease cancer color blind)',
#   '(skin blind cancer color also known)',
#   '(skin cancer blind color seen)',
#   '(skin cancer blind largely)',
#   '(skin disease cancer color blind)',
#   '(skin phenomenon cancer color blind)',
#   '(condition skin cancer color blind)',
#   '(skin cancer blind color seen)',
#   '(skin process cancer color blind)',
#   '(skin cancer tumor color blind)',
#   '(skin cancer color issue blind)',
#   '(skin cancer problem color blind)',
#   '(skin cancer color blind disorder)',
#   '(skin cancer thing color blind)',
#   '(skin cancer color primarily blind)',
#   '(skin cancer color mainly blind)',
#   '(skin cancer color also blind)',
#   '(skin cancer color mostly blind)',
#   '(skin cancer color largely blind)',
#   '(skin cancer blind color)',
#   '(skin cancer blind color)',
#   '(purely skin cancer color blind)',
#   '(skin cancer predominantly color blind)',
#   '(skin essentially cancer color blind)',
#   '(skin cancer blind color)',
#   '(skin cancer actually color blind)',
#   '(skin cancer blind usually color)',
#   '(skin cancer blind color)'],
#  ['(never chemotherapy adverse)',
#   '(adverse side effects chemotherapy also known)',
#   '(negative side effects chemotherapy also known)',
#   '(adverse effects side chemotherapy also known)',
#   '(adverse effects side chemotherapy also associated)',
#   '(effect negative side chemotherapy children)',
#   '(always chemotherapy negative)',
#   '(always chemotherapy adverse)',
#   '(chemotherapy side effect negative)',
#   '(side chemotherapy effects adverse known)',
#   '(side chemotherapy effects negative known)',
#   '(effects history adverse side chemotherapy)',
#   '(always effect negative side chemotherapy)',
#   '(effects adverse side chemotherapy never)',
# ...
#   '(antioxidant cancer medications lung (used OR prevent))',
#   '(antioxidant cancer drugs lung (used OR treat))',
#   '(antioxidant lung cancer helpful also drugs preventing)',
#   '(antioxidant cancer medications lung (used OR treat))',
#   '(antioxidant cancer drugs lung (used OR fight))',
#   '(tablets antioxidant cancer lung (fight OR used))',
#   '(antioxidant cancer medications lung (fight OR used))',
#   '(antioxidant cancer drugs lung (help OR occurring OR prevent))',
#   '(antioxidant medications lung cancer also helpful preventing)',
#   '(antioxidant cancer medications lung (help OR occurring OR prevent))',
#   '(antioxidant cancer drugs lung (combat OR used))',
#   '(antioxidant cancer drugs lung (reduce OR used))',
#   '(antioxidant cancer medications lung (combat OR used))',
#   '(antioxidant lung cancer also drugs prevention help)',
#   '(antioxidant cancer medications lung (used OR reduce))',
#   '(therapy antioxidant cancer product lung)',
#   '(antioxidant lung cancer drugs prevention help)',
#   '(antioxidant lung cancer also drugs (help OR prevent))',
#   '(antioxidant medications lung cancer prevention help)',
#   '(antioxidant cancer drugs lung (fight OR used))',
#   '(antioxidant lung risk cancer drugs (reduce OR help))',
#   '(antioxidant cancer drugs lung (prevent OR help))',
#   '(antioxidant cancer medications lung (prevent OR help))',
#   '(antioxidant cancer drugs lung (fight OR help))',
#   '(antioxidant cancer drugs lung (reduce OR help))',
#   '(antioxidant cancer medications lung (fight OR help))',
#   '(antioxidant cancer medications lung (reduce OR help))',
#   '(antioxidant cancer drugs lung prevent)',
#   '(lung supplements cancer antioxidant (used OR fight))',
#   '(antioxidant cancer also lung drugs prevention helpful)',
#   '(antioxidant cancer also lung drugs helpful)',
#   '(antioxidant cancer medications also lung helpful)',
#   '(antioxidant cancer medications lung used)',
#   '(lung supplements cancer antioxidant (prevent OR help))',
#   '(antioxidant cancer drugs lung help)',
#   '(antioxidant cancer medications lung help)',
#   '(antioxidant cancer drugs lung protect)',
#   '(antioxidant cancer medications lung protect)'],
#  ['(risk result cancer breast fertilisation vitro rises)',
#   '(fertilization risk result cancer breast vitro rises)',
#   '(fertilization risk breast cancer also vitro raised)',
#   '(fertilization risk breast cancer also vitro raised)',
#   '(fertilization risk breast cancer also vitro increased)',
#   '(fertilization risk cancer breast also vitro elevated)',
#   '(fertilization risk cancer breast vitro elevated)',
#   '(fertilization risk breast cancer vitro increased)',
#   '(fertilization risk breast cancer vitro raised)',
#   '(fertilization risk cancer breast vitro elevated)',
#   '(fertilization risk breast cancer also vitro raised)',
#   '(fertilization risk breast cancer vitro goes)',
#   '(fertilization risk cancer breast indefinitely vitro risen)',
#   '(fertilization risk result cancer breast vitro goes)',
#   '(fertilization risk result cancer breast vitro rise)',
#   '(fertilization risk result cancer breast vitro rises)',
#   '(fertilization risk result cancer breast vitro rises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk cancer breast vitro risen)',
#   '(fertilization risk cancer breast vitro goes)',
#   '(fertilization risk cancer breast vitro elevated)',
#   '(cancer fertilization breast risk vitro elevated)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization chance breast cancer vitro raises)',
#   '(increases cancer fertilization breast result risk vitro)',
#   '(fertilization risk cancer breast vitro risen)',
#   '(fertilization risk cancer breast vitro risen)',
#   '(fertilization since risk cancer breast vitro risen)',
#   '(fertilization risk cancer breast vitro elevated)',
#   '(fertilization risk dramatically cancer breast vitro risen)',
#   '(fertilization risk significantly cancer breast vitro risen)',
#   '(fertilization risk breast cancer vitro increases)',
#   '(fertilization risk breast cancer also vitro raises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk cancer breast vitro risen)',
#   '(fertilization risk breast cancer vitro raise)',
#   '(fertilization risk cancer breast vitro risen)',
#   '(fertilization women risk breast cancer vitro raises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk breast cancer vitro (raise OR may))',
#   '(fertilization risk elderly breast cancer vitro raises)',
#   '(increases breast fertilization cancer risk vitro)',
#   '(fertilization risk cancer breast vitro raises)',
#   '(fertilization risk cancer breast vitro rises)',
#   '(fertilization risk breast cancer vitro raises)',
#   '(fertilization risk cancer breast vitro elevates)',
#   '(fertilization risk cancer breast vitro increases)',
#   '(fertilization risk cancer breast vitro increases)'],
#  ['(citizens among cancer breast rare senior)',
#   '(breast cancer age women exclusive)',
#   '(citizens breast cancer exclusive senior)',
#   '(senior citizens breast cancer limited)',
#   '(elderly breast cancer people exclusive)',
#   '(elderly people breast cancer limited)',
#   '(senior citizens breast cancer restricted)',
#   '(breast cancer people exclusive old)',
#   '(elderly people breast cancer restricted)',
#   '(breast seniors cancer exclusive)',
#   '(elderly people breast cancer affects)',
#   '(breast seniors cancer limited)',
#   '(breast elders cancer exclusive)',
#   '(breast seniors cancer restricted)',
#   '(females breast exclusive cancer)',
#   '(breast cancer seniors affects)',
#   '(breast cancer older people exclusive)',
#   '(people cancer older breast limited)',
#   '(people cancer older breast restricted)',
#   '(cancer breast older women exclusive)',
#   '(women cancer older breast limited)',
#   '(cancer breast older people exclusive)',
#   '(adults cancer breast exclusive old)',
#   '(unique cancer older breast people)',
#   '(adults cancer breast older rare)',
#   '(people cancer older breast confined)',
#   '(people breast cancer older limited)',
#   '(adults among cancer older breast rare)',
#   '(women breast cancer older restricted)',
#   '(adults breast cancer older affect)',
#   '(breast cancer older individuals exclusive)',
#   '(people breast cancer older affects)',
#   '(elderly adults breast cancer affects)',
#   '(adults older peculiarly breast cancer limited)',
#   '(adults breast cancer older limited)',
#   '(adults breast cancer older exclusive)',
#   '(adults breast cancer older limited)',
#   '(adults breast cancer older restricted)',
#   '(adults breast cancer older exclusive)',
#   '(adults unique breast older cancer)',
#   '(adults breast cancer older confined)',
#   '(adults breast cancer older limited)',
#   '(adults breast specific older cancer)',
#   '(adults breast cancer older restricted)',
#   '(adults breast cancer older exclusive)',
#   '(adults breast cancer older affects)',
#   '(adults breast cancer older affects)',
#   '(adults breast cancer older restricted)',
#   '(adults breast cancer older limited)',
#   '(adults breast cancer older exclusive)'],
#  ['(risks result nipple cancer breast piercings rise)',
#   '(risks rise nipple piercings cancer breast)',
#   '(risk piercing result nipple cancer breast rises)',
#   '(risks nipple piercings cancer breast risen)',
#   '(risks nipple piercings cancer breast also elevated)',
#   '(risks thanks nipple cancer breast piercings risen)',
#   '(risks nipple piercings cancer breast increased)',
#   '(risks nipple piercings cancer breast risen)',
#   '(risks nipple breast piercings cancer raised)',
#   '(risks nipple piercings cancer breast increased)',
#   '(risks nipple piercings cancer breast elevated)',
#   '(risk breast piercings cancer nitpickle heightened)',
#   '(risks thanks nipple piercings cancer breast rise)',
#   '(risks nipple piercings cancer breast risen)',
#   '(risks nipple piercings cancer breast risen)',
#   '(risks nipple piercings cancer breast risen)',
#   '(risks thanks nipple piercings cancer breast rise)',
#   '(nifty risk cancer piercings breast raised)',
#   '(nifty risk thanks cancer piercings breast rises)',
#   '(risks nipple cancer piercings breast rise)',
#   '(risk cancer piercings breast nitpickle rises)',
#   '(increases cancer piercings breast nitpickle risk)',
#   '(nifty risk cancer piercings breast rises)',
#   '(increases cancer piercings breast result nipple risk)',
#   '(risk thanks nipple cancer piercings breast rises)',
#   '(risk nipple piercings cancer breast heightened)',
#   '(risk nipple breast piercings cancer raised)',
#   '(risk thanks nipple piercings cancer breast rises)',
#   '(risk nipple piercings cancer breast heightened)',
#   '(risk nipple piercings cancer breast elevated)',
#   '(risk nipple piercings cancer breast increased)',
#   '(risk thanks nipple piercings cancer breast increases)',
#   '(risk nipple piercings cancer breast risen)',
#   '(risk nipple piercings cancer breast risen)',
#   '(risk nipple cancer piercings due breast rises)',
#   '(risk nipple breast piercings cancer raised)',
#   '(risk thanks nipple piercings cancer breast increases)',
#   '(risk nipple piercings cancer breast risen)',
#   '(risk nipple cancer piercings due breast rises)',
#   '(risk nipple piercings cancer breast elevated)',
#   '(risk nipple piercings cancer breast risen)',
#   '(risk nipple piercings cancer breast increased)',
#   '(risk nipple piercings cancer breast increased)',
#   '(risk nipple piercings cancer breast rises)',
#   '(increases nipple piercings cancer breast risk)',
#   '(risk nipple piercings cancer breast rises)',
#   '(increases nipple piercings cancer breast risk)',
#   '(increases nipple piercings cancer breast risk)',
#   '(risk nipple piercings cancer breast rises)',
#   '(risk nipple piercings cancer breast rises)'],
#  ['(counterpart male breast cancer)',
#   '(among cancer problem breast women)',
#   '(among cancer males common breast)',
#   '(male issue breast cancer)',
#   '(men women breast cancer affect)',
#   '(male breast cancer problem)',
#   '(condition male breast cancer)',
#   '(among cancer males breast exist)',
#   '(breast cancer males appear)',
#   '(breast cancer males occur)',
#   '(among cancer males breast occur)',
#   '(condition male breast cancer)',
#   '(among cancer males breast happen)',
#   '(breast cancer males exist)',
#   '(male disease breast cancer)',
#   '(women breast cancer affect)',
#   '(breast cancer males affect)',
#   '(cancer breast appear)',
#   '(patients cancer breast affect)',
#   '(cancer breast occur)',
#   '(cancer breast affect)',
#   '(men among cancer problem breast)',
#   '(men cancer problem breast)',
#   '(men cancer problem breast)',
#   '(men among cancer problem breast)',
#   '(men among cancer breast epidemic)',
#   '(men disease among cancer breast)',
#   '(men breast cancer problem)',
#   '(men breast cancer occur)',
#   '(men breast cancer appear)',
#   '(men breast cancer happen)',
#   '(men among cancer common breast)',
#   '(men breast cancer cause)',
#   '(men breast cancer happen)',
#   '(men breast cancer exist)',
#   '(men breast cancer affect)',
#   '(men among cancer breast exist)',
#   '(men among cancer breast occur)',
#   '(men among cancer breast happen)',
#   '(men breast cancer common)',
#   '(men present breast cancer)',
#   '(men breast cancer limited)',
#   '(men breast cancer exclusive)',
#   '(men breast cancer develop)',
#   '(men breast cancer affect)',
#   '(men breast cancer affecting)',
#   '(men breast cancer affect)',
#   '(men breast cancer attack)',
#   '(men breast cancer kill)',
#   '(men cancer breast get)'],
#  ['(product breast cancer mammograms carried)',
#   '(product mammograms breast cancer also transmitted)',
#   '(product breast cancer mammograms transmitted)',
#   '(product breast cancer mammograms spreading)',
#   '(mammograms result cancer breast spreading)',
#   '(product mammograms breast cancer also spread)',
#   '(product breast cancer mammograms spread)',
#   '(result cancer mammograms breast spread)',
#   '(product breast cancer mammograms spread)',
#   '(product breast cancer mammograms spread)',
#   '(product breast cancer mammograms spread)',
#   '(rise breast cancer also mammograms)',
#   '(mammograms result cancer breast risen)',
#   '(mammograms result cancer breast)',
#   '(breast cancer mammograms carried)',
#   '(result cancer breast also mammograms)',
#   '(tandem breast cancer mammograms risen)',
#   '(rise cancer mammograms breast)',
#   '(cancer breast common occurrence mammograms)',
#   '(disease cancer breast common mammograms)',
#   '(disease cancer breast common mammograms)',
#   '(disease among cancer common breast mammograms)',
#   '(mammograms disease cancer breast common spread)',
#   '(also cancer mammograms breast spreading)',
#   '(product cancer mammograms breast)',
#   '(result cancer mammograms breast)',
#   '(responsible breast cancer also mammograms)',
#   '(also breast cancer mammograms distributed)',
#   '(breast mammograms cancer transmitted)',
#   '(infectious breast mammograms cancer)',
#   '(also breast cancer mammograms spreading)',
#   '(mammograms result cancer breast expected)',
#   '(cause breast cancer common mammograms)',
#   '(cause breast cancer common mammograms)',
#   '(also breast cancer mammograms spread)',
#   '(breast cancer easily mammograms spread)',
#   '(mammograms breast cancer due also spreading)',
#   '(breast cancer mammograms (grow OR expected))',
#   '(breast cancer mammograms (increase OR expected))',
#   '(breast cancer mammograms (grow OR expected))',
#   '(breast mammograms cancer spread)',
#   '(also breast cancer mammograms spread)',
#   '(breast cancer easily mammograms spread)',
#   '(breast mammograms cancer spread)',
#   '(breast cancer mammograms (spread OR expected))',
#   '(tendency breast cancer mammograms spread)',
#   '(breast cancer mammograms (spread OR expected))',
#   '(likely breast cancer mammograms spread)',
#   '(also breast cancer mammograms (causing OR spread))',
#   '(breast cancer mammograms (spread OR causing))'],
#  ['(surgery canal root cancers linked)',
#   '(canal root cancer result surgery)',
#   '(therapy result canal root cancer)',
#   '(result canal root cancer surgeries)',
#   '(surgery canal root cancer caused)',
#   '(treatments result canal root cancer)',
#   '(canal root cancer result surgery)',
#   '(result canal root cancer treatment)',
#   '(canal root cancer product surgery)',
#   '(interventions canal root cancer result)',
#   '(result canal root intervention cancer)',
#   '(techniques result canal root cancer)',
#   '(surgeries canal root cancer caused)',
#   '(canal root cancer product surgery)',
#   '(surgery canal root cancer linked)',
#   '(surgery canal root cancer caused)',
#   '(surgery canal root cancer associated)',
#   '(surgery canal root cancer related)',
#   '(surgeries canal root cancer linked)',
#   '(surgeries canal root cancer caused)',
#   '(treatments canal root cancer caused)',
#   '(techniques canal root cancer caused)',
#   '(treatments canal root cancer linked)',
#   '(therapy canal root cancer associated)',
#   '(procedures canal root cancers linked)',
#   '(therapy canal root cancer linked)',
#   '(canal root common cancer surgery)',
#   '(surgeries canal root cancer associated)',
#   '(therapy canal root cancer caused)',
#   '(procedures canal root cancers associated)',
#   '(canal root common cancer surgery following)',
#   '(canal cancerous root common procedures)',
#   '(result canal root cancer procedures)',
#   '(procedures canal root cancer caused)',
#   '(result canal root cancer procedures)',
#   '(procedures surgical canal root cancer caused)',
#   '(procedures canal root cancer surgery linked)',
#   '(procedures surgical canal root cancer linked)',
#   '(procedures canal root cancer also linked)',
#   '(procedures canal root cancer caused)',
#   '(procedures canal root cancer linked)',
#   '(procedures canal root cancer associated)',
#   '(procedures canal root cancer related)',
#   '(canal root common cancer among procedures)',
#   '(canal root cancer present procedures)',
#   '(canal root common cancer procedures)',
#   '(canal root common cancer procedures)',
#   '(procedures canal root cancer triggered)',
#   '(canal procedures cancer result root)',
#   '(procedures canal cancer cause root)']]

# %%
hoaxdf['keyword_paraphrases'] = query_builder_paraphrases_filtered

# %%
hoax_key_queries = []
for hoax in tqdm(hoaxdf['Normalized Hoax-checked']):
  statement = get_kw_comb_v2(statement_text=hoax , 
                              language_code="en", # <-- Important
                              lemmatized=False, 
                              level = 0, # <- keywords per combination =  n - level
                              top_n = 7, 
                              diversity = 0.2, 
                              max_query_len = 1024
                              )[0]
  if isinstance(statement, list):
    statement = statement[0]
  hoax_key_queries.append(statement)
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   2%|▏         | 1/52 [00:00<00:17,  2.84it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   4%|▍         | 2/52 [00:00<00:14,  3.34it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   6%|▌         | 3/52 [00:00<00:14,  3.29it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#   8%|▊         | 4/52 [00:01<00:13,  3.58it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  10%|▉         | 5/52 [00:01<00:13,  3.59it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  12%|█▏        | 6/52 [00:01<00:12,  3.83it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  13%|█▎        | 7/52 [00:01<00:10,  4.14it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  15%|█▌        | 8/52 [00:02<00:12,  3.63it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  17%|█▋        | 9/52 [00:02<00:15,  2.79it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  19%|█▉        | 10/52 [00:03<00:18,  2.27it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  21%|██        | 11/52 [00:03<00:17,  2.32it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  23%|██▎       | 12/52 [00:04<00:17,  2.28it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  25%|██▌       | 13/52 [00:04<00:15,  2.46it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  27%|██▋       | 14/52 [00:04<00:15,  2.45it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  29%|██▉       | 15/52 [00:05<00:14,  2.62it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  31%|███       | 16/52 [00:05<00:13,  2.75it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  33%|███▎      | 17/52 [00:06<00:13,  2.66it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  35%|███▍      | 18/52 [00:06<00:13,  2.50it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  37%|███▋      | 19/52 [00:07<00:16,  2.00it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  38%|███▊      | 20/52 [00:07<00:17,  1.85it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  40%|████      | 21/52 [00:08<00:17,  1.77it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  42%|████▏     | 22/52 [00:09<00:18,  1.66it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  44%|████▍     | 23/52 [00:09<00:15,  1.82it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  46%|████▌     | 24/52 [00:10<00:14,  1.92it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  48%|████▊     | 25/52 [00:10<00:12,  2.23it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  50%|█████     | 26/52 [00:10<00:10,  2.41it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  52%|█████▏    | 27/52 [00:11<00:09,  2.54it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  54%|█████▍    | 28/52 [00:11<00:09,  2.65it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  56%|█████▌    | 29/52 [00:11<00:08,  2.61it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  58%|█████▊    | 30/52 [00:12<00:08,  2.54it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  60%|█████▉    | 31/52 [00:12<00:07,  2.65it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  62%|██████▏   | 32/52 [00:12<00:07,  2.69it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  63%|██████▎   | 33/52 [00:13<00:06,  2.94it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  65%|██████▌   | 34/52 [00:13<00:05,  3.01it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  67%|██████▋   | 35/52 [00:13<00:05,  3.00it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  69%|██████▉   | 36/52 [00:14<00:07,  2.12it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  71%|███████   | 37/52 [00:14<00:06,  2.37it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  73%|███████▎  | 38/52 [00:15<00:04,  2.86it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  75%|███████▌  | 39/52 [00:15<00:03,  3.30it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  77%|███████▋  | 40/52 [00:15<00:03,  3.64it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  79%|███████▉  | 41/52 [00:15<00:02,  3.86it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  81%|████████  | 42/52 [00:15<00:02,  3.74it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  83%|████████▎ | 43/52 [00:16<00:02,  3.86it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  85%|████████▍ | 44/52 [00:16<00:01,  4.13it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  87%|████████▋ | 45/52 [00:16<00:01,  4.39it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  88%|████████▊ | 46/52 [00:16<00:01,  4.38it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  90%|█████████ | 47/52 [00:17<00:01,  4.33it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  92%|█████████▏| 48/52 [00:17<00:00,  4.53it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  94%|█████████▍| 49/52 [00:17<00:00,  4.42it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  96%|█████████▌| 50/52 [00:17<00:00,  4.65it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
#  98%|█████████▊| 51/52 [00:17<00:00,  4.44it/s]/usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# 100%|██████████| 52/52 [00:18<00:00,  2.86it/s]

# %%
hoaxdf['hoax_key_queries'] = hoax_key_queries

# %%
 hoaxdf
# Out:
#               Fact checker, institution  \
# 0                            PolitiFact
# 1                            PolitiFact
# 2                            PolitiFact
# 3                            PolitiFact
# 4                            PolitiFact
# 5                            PolitiFact
# 6                            PolitiFact
# 7                            PolitiFact
# 8                            PolitiFact
# 9                            PolitiFact
# 10                        Factcheck.org
# 11                             FullFact
# 12                             FullFact
# 13                             FullFact
# 14  Cancer Treatment Centers of America
# 15  Cancer Treatment Centers of America
# 16  Cancer Treatment Centers of America
# 17  Cancer Treatment Centers of America
# 18  Cancer Treatment Centers of America
# 19  Cancer Treatment Centers of America
# 20  Cancer Treatment Centers of America
# 21  Cancer Treatment Centers of America
# 22  Cancer Treatment Centers of America
# 23  Cancer Treatment Centers of America
# 24                   Cancer Research UK
# 25                   Cancer Research UK
# 26                   Cancer Research UK
# 27                   Cancer Research UK
# 28                   Cancer Research UK
# 29                   Cancer Research UK
# 30                   Cancer Research UK
# 31                   Cancer Research UK
# 32                   Cancer Research UK
# 33                   Medical News Today
# 34                   Medical News Today
# 35                   Medical News Today
# 36                   Medical News Today
# 37                   Medical News Today
# 38                   Medical News Today
# 39                   Medical News Today
# 40                   Medical News Today
# 41                   Medical News Today
# 42                   Medical News Today
# 43                   Medical News Today
# 44                   Medical News Today
# 45                   Medical News Today
# 46                   Medical News Today
# 47                   Medical News Today
# 48                   Medical News Today
# 49                   Medical News Today
# 50                   Medical News Today
# 51                   Medical News Today
#
#                               Normalized Hoax-checked  \
# 0   huge spike in soft-tissue cancers diagnoses in...
# 1   Cancer institute finally admits marijuana kill...
# 2   No one has died of cancer or heart disease sin...
# 3   80% of children born in developing countries d...
# 4   Cutting out sugar and drinking hot lemon water...
# 5      Abortion increases the risk of breast cancer.
# 6          The flu shot is designed to spread cancer.
# 7   Dandelion root is able to kill 98% of cancer c...
# 8   A molecule found in a Himalayan fungus kills c...
# 9   Cancer and matters to do with kidney failure k...
# 10                         Polio vaccine cause cancer
# 11  Rubbing hydrogen peroxide over your body every...
# 12                Antiperspirant causes breast cancer
# 13  Having 10 or more sexual partners increases ca...
# 14               Getting a biopsy makes cancer spread
# 15                 Eating sugar causes cancer to grow
# 16       You won’t need surgery if the tumor is solid
# 17                         Skin cancer is color blind
# 18           Chemotherapy always has bad side effects
# 19      A lump in your breast is always breast cancer
# 20          Pregnant women can’t get cancer treatment
# 21       Hair will never grow back after chemotherapy
# 22                       Cancer will always come back
# 23  Oncologists don’t want patients trying unusual...
# 24                                Phones cause cancer
# 25                   Eating burnt foods cause cancer
# 26        Plastic bottles and containers cause cancer
# 27                 Artificial sweeteners cause cancer
# 28            Genetically modified foods cause cancer
# 29  Eating foods grown on farms that use pesticide...
# 30             Use toiletries and makeup cause cancer
# 31               Milk and dairy products cause cancer
# 32                                Stress cause cancer
# 33                           Power lines cause cancer
# 34             Cancer surgery causes cancer to spread
# 35                 Wearing a bra causes breast cancer
# 36                   Herbal medicines can cure cancer
# 37                        There is no cure for cancer
# 38                   Only smokers develop lung cancer
# 39     There is no way to reduce the lung cancer risk
# 40               nly older adults develop lung cancer
# 41  Living in a polluted city is worse than smokin...
# 42  Breathing in talcum powder increases lung canc...
# 43                  Lung cancer always shows symptoms
# 44                     Lung cancer is always terminal
# 45  Antioxidant supplements protect against lung c...
# 46  In vitro fertilization increases the risk of b...
# 47         Breast cancer only happens to older adults
# 48       Nipple piercings increase breast cancer risk
# 49                       Men do not get breast cancer
# 50           Mammograms cause breast cancer to spread
# 51                 Root canal procedures cause cancer
#
#      Original hoax Text from source or article tittle  \
# 0   Soft-tissue cancer diagnoses have “climbed thr...
# 1   "Cancer institute finally admits marijuana kil...
# 2   “No one has died of cancer or heart disease si...
# 3   "80% of children born in developing countries ...
# 4   Says cutting out sugar and drinking hot lemon ...
# 5   Says abortion increases the risk of breast can...
# 6       The flu shot is "designed to spread cancer."
# 7   "Dandelion root is able to kill 98% of cancer ...
# 8   A molecule found in a Himalayan fungus "kills ...
# 9   "Cancer and matters to do with kidney failure ...
# 10                Did the Polio Vaccine Cause Cancer?
# 11  Rubbing hydrogen peroxide over your body every...
# 12  The role of antiperspirant in causing breast c...
# 13  Women who have had 10 or more sexual partners ...
# 14               Getting a biopsy makes cancer spread
# 15                 Eating sugar causes cancer to grow
# 16       You won’t need surgery if the tumor is solid
# 17                         Skin cancer is color blind
# 18           Chemotherapy always has bad side effects
# 19      A lump in your breast is always breast cancer
# 20          Pregnant women can’t get cancer treatment
# 21       Hair will never grow back after chemotherapy
# 22                       Cancer will always come back
# 23  Oncologists don’t want patients trying unusual...
# 24                     Do mobile phones cause cancer?
# 25              Can eating burnt foods cause cancer?
# 26  Does using plastic bottles and containers caus...
# 27             Do artificial sweeteners cause cancer?
# 28        Do genetically modified foods cause cancer?
# 29         Can pesticides or herbicides cause cancer?
# 30                           Cosmetics and toiletries
# 31          Can milk and dairy products cause cancer?
# 32                           Can stress cause cancer?
# 33                           Power lines cause cancer
# 34             Cancer surgery causes cancer to spread
# 35                 Wearing a bra causes breast cancer
# 36                   Herbal medicines can cure cancer
# 37                        There is no cure for cancer
# 38                   Only smokers develop lung cancer
# 39     There is no way to reduce the lung cancer risk
# 40               nly older adults develop lung cancer
# 41  Living in a polluted city is worse than smokin...
# 42  Breathing in talcum powder increases lung canc...
# 43        If I had lung cancer, I would have symptoms
# 44                     Lung cancer is always terminal
# 45  Antioxidant supplements protect against lung c...
# 46            IVF increases the risk of breast cancer
# 47         Breast cancer only happens to older adults
# 48       Nipple piercings increase breast cancer risk
# 49                       Men do not get breast cancer
# 50           Mammograms cause breast cancer to spread
# 51        Root canals and cancer: Debunking the myths
#
#                       filtered_sorted_top_paraphrases  \
# 0   [As a result of the COVID-19 vaccines, there w...
# 1   [The marijuana research has now confirmed that...
# 2   [Since the COVID-19 thing was in existence, no...
# 3   [Every year, 80 percent of children in develop...
# 4   [Cancer can be reversed by a diet change and h...
# 5   [Breast cancer prevention goes hand in hand wi...
# 6   [The flu shot is supposed to cause disease in ...
# 7   [In less than a week, Dandelion root can destr...
# 8   [Cancer cells are killed by a molecule isolate...
# 9   [More people die in Kenya today from cancer an...
# 10  [Cancer is a result of the vaccination program...
# 11  [Every day, a raging hydrogen peroxide solutio...
# 12  [Breast cancer is a result of antiperspirants....
# 13  [Both male and female cancer risk rises with t...
# 14  [A biopsy can help with tumor formation., A bi...
# 15  [Cancer cells will increase as a result of die...
# 16  [If the tumor is solid, there will not be need...
# 17  [Skin cancer is a colorblind disease., Skin ca...
# 18  [Chemotherapy has never had adverse side-effec...
# 19  [Breast cancer is also a sign of breast cancer...
# 20  [Breast cancer survivors are unlikely to recei...
# 21  [Since being treated with chemotherapy, hair w...
# 22  [Cancer will never return to the United States...
# 23  [Patients are unlikely to be interested in exp...
# 24  [Smartphones are cancerous., Smartphones are t...
# 25  [Cancer is caused by burningt foods., Cancer i...
# 26  [Plastic bottles and cans are carcinogenic., P...
# 27  [Artificial sweeteners have cancerous effects....
# 28  [Cancer is a disease linked to genetic modific...
# 29  [Growing vegetables on farms that use pesticid...
# 30  [When using toiletries and makeup, cancer is t...
# 31  [Cancer is a result of breast and dairy produc...
# 32  [Stress causes cancerous tumor formation., Str...
# 33  [Power lines lead to tumor formation., Power l...
# 34  [Cancer is the product of a cancer treatment c...
# 35  [Breast cancer is caused by wearing braces., r...
# 36  [Herbal drugs have been shown to prevent cance...
# 37  [Tumors are not curable., Cancer does not have...
# 38  [Nicotine users are the only ones with lung ca...
# 39  [There is no way to minimize the risks of lung...
# 40  [Lung cancer is the most common disease among ...
# 41  [Living in a polluted area raises the risk of ...
# 42  [The risk of lung cancer rises as a result of ...
# 43  [Lung cancer is a common disease in the United...
# 44  [All lung cancers are terminal., All lung canc...
# 45  [Antioxidant drugs are also anti-lung cancer d...
# 46  [Breast cancer risk rises as a result of in vi...
# 47  [Breast cancer is rare among senior citizens.,...
# 48  [Breast cancer risks rise as a result of Nippl...
# 49  [Breast cancer does not have a male counterpar...
# 50  [Breast cancer is the product of mammograms, w...
# 51  [Cancers are linked to root canal surgery., Ca...
#
#                                   keyword_paraphrases  \
# 0   [(((2021 OR 2.021)) rise cancer tissue vaccine...
# 1   [(cancer research (cause OR confirmed) marijua...
# 2   [(heart existence since one cancer died covid-...
# 3   [((("eighty" OR 80)) percent nations cancer ye...
# 4   [(hot water diet cancer lemon change reversed)...
# 5   [(hand abortions cancer breast prevention goes...
# 6   [(humans disease flu shot (supposed OR cause))...
# 7   [((98%) less dandelion week tumor root destroy...
# 8   [((("forty" OR 40)) molecule cells fungus pote...
# 9   [(kidney tuberculosis cancer (killed OR aids O...
# 10  [(vaccination result cancer program), (vaccina...
# 11  [(body day every hydrogen solution peroxide ra...
# 12  [(antiperspirants result breast cancer), (anti...
# 13  [(ten sexual risk partners cancer female rises...
# 14  [(formation biopsy tumor help), (biopsy cancer...
# 15  [(cells sugar diet result cancer increase), (s...
# 16  [(surgery tumor solid needing), (surgery tumor...
# 17  [(skin disease cancer colorblind), (skin pheno...
# 18  [(never chemotherapy adverse), (adverse side e...
# 19  [(breast also cancer sign), (lump breast cance...
# 20  [(unlikely survivors cancer breast treatment r...
# 21  [(since chemotherapy hair never (treated OR re...
# 22  [(cancer never return (united OR states)), (al...
# 23  [(therapies oncologists unlikely experimental ...
# 24  [(smartphones cancerous), (product smartphones...
# 25  [(burningt cancer foods caused), (result cance...
# 26  [(carcinogenic bottles plastic cans), (bottles...
# 27  [(sweeteners artificial cancerous effects), (s...
# 28  [(modification genetic foods disease cancer li...
# 29  [(pesticides herbicides risk vegetables cancer...
# 30  [(makeup toiletries result cancer using), (mak...
# 31  [(result breast cancer products dairy), (resul...
# 32  [(stress formation cancerous tumor causes), (s...
# 33  [(formation power tumor lines lead), (power ca...
# 34  [(product treatment cancer center), (treatment...
# 35  [(cancer braces breast (wearing OR caused)), (...
# 36  [(herbal cancer drugs (shown OR prevent)), (he...
# 37  [(curable tumors), (cancer cure), (cancer drug...
# 38  [(ones cancer users nicotine lung), (lung suff...
# 39  [(country risks lung way cancer minimize), (th...
# 40  [(disease among cancer common lung seniors), (...
# 41  [(area polluted lung risk cancer (raises OR li...
# 42  [(bronchial lung risk exposure result cancer r...
# 43  [(lung disease cancer common (united OR states...
# 44  [(lung cancers terminal), (lung cases cancer t...
# 45  [(antioxidant cancer drugs also), (antioxidant...
# 46  [(risk result cancer breast fertilisation vitr...
# 47  [(citizens among cancer breast rare senior), (...
# 48  [(risks result nipple cancer breast piercings ...
# 49  [(counterpart male breast cancer), (among canc...
# 50  [(product breast cancer mammograms carried), (...
# 51  [(surgery canal root cancers linked), (canal r...
#
#                                      hoax_key_queries
# 0   (((2021 OR 2.021)) spike vaccines huge cancers...
# 1   (marijuana finally (kills OR admits) (cancer O...
# 2   (since one cancer heart (started OR died) covi...
# 3   ((80%) countries cancer children (developing O...
# 4   (hot water sugar cancer lemon (drinking OR cure))
# 5             (abortion risk breast cancer increases)
# 6              (flu cancer shot (designed OR spread))
# 7   ((("forty-eight" OR 48) OR 98%) hours dandelio...
# 8   ((("forty" OR 40)) molecule cells fungus poten...
# 9   (tuberculosis malaria cancer kidney aids kill ...
# 10                       (vaccine cancer polio cause)
# 11  (body day every hydrogen cancer peroxide rubbing)
# 12              (antiperspirant breast cancer causes)
# 13  (((10 OR "ten")) men sexual partners cancer wo...
# 14       (biopsy cancer (spread OR getting OR makes))
# 15          (sugar cancer (grow OR eating OR causes))
# 16                         (surgery tumor solid need)
# 17                          (skin cancer blind color)
# 18             (side bad always effects chemotherapy)
# 19                        (lump always breast cancer)
# 20              (treatment women cancer pregnant get)
# 21                (chemotherapy back hair never grow)
# 22                          (back always cancer come)
# 23  (patients treatments unusual oncologists (want...
# 24                              (phones cancer cause)
# 25          (cancer foods (cause OR eating OR burnt))
# 26          (bottles cancer plastic containers cause)
# 27               (sweeteners artificial cancer cause)
# 28     (cancer foods genetically (modified OR cause))
# 29  (pesticides herbicides risk foods cancer farms...
# 30               (cause toiletries makeup cancer use)
# 31                 (dairy cancer products milk cause)
# 32                              (stress cancer cause)
# 33                         (power cancer lines cause)
# 34                (surgery cancer (spread OR causes))
# 35            (bra breast cancer (wearing OR causes))
# 36                     (herbal cancer medicines cure)
# 37                                      (cancer cure)
# 38                      (lung cancer smokers develop)
# 39                      (way cancer risk lung reduce)
# 40             (adults older lung cancer nly develop)
# 41     (city polluted lung risk worse cancer smoking)
# 42  (lung risk cancer powder (increases OR breathi...
# 43                (lung always cancer symptoms shows)
# 44                      (lung always cancer terminal)
# 45      (lung supplements cancer antioxidant protect)
# 46  (fertilization risk cancer breast vitro increa...
# 47               (adults breast cancer older happens)
# 48     (risk nipple piercings cancer breast increase)
# 49                            (men cancer breast get)
# 50       (breast cancer mammograms (spread OR cause))
# 51               (canal procedures cancer cause root)

# %% [markdown]
# Columns:
#
# Original hoad: Normalized hoax-checked
#
# Original hoax keyword query = hoax_key_queries
#
# Paraphrases filtered = filtered_sorted_top_paraphrases
#
# Paraphrases keyword queries = keyword_paraphrases

# %% [markdown]
# #Generating final query

# %% [markdown]
# Removing redundant keyword paraphrases

# %%
lexically_enriched_final_query_list = []
for n in tqdm(range(len(hoaxdf))):
  final_query = []
  final_query.append(hoaxdf['hoax_key_queries'][n])
  for paraphrase in hoaxdf['keyword_paraphrases'][n]:
    max_score=0
    for candidate in final_query:
      score = jaccard_similarity(candidate, paraphrase, ngram=1)
      if score > max_score:
        max_score =  score
    if max_score != 1:
      final_query.append(paraphrase)
  lexically_enriched_final_query_list.append(final_query)
# Out:
# 100%|██████████| 52/52 [00:12<00:00,  4.24it/s]

# %%
lexically_enriched_final_query_list[0]
# Out:
# ['(((2021 OR 2.021)) spike vaccines huge cancers covid-19)',
#  '(((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19)',
#  '(((2021 OR 2.021)) rise diagnoses cancer vaccinations covid-19)',
#  '(((2021 OR 2.021)) rise significant cancer vaccinations covid-19)',
#  '(((2021 OR 2.021)) rise vaccines cancer diagnosis covid-19)',
#  '(((2021 OR 2.021)) cancer tissue vaccines surge soft covid-19)',
#  '(((2021 OR 2.021)) diagnoses cancer surge vaccinations covid-19)',
#  '(((2021 OR 2.021)) rise vaccines significant cancer covid-19)',
#  '(((2021 OR 2.021)) diagnoses vaccines cancer rise covid-19)',
#  '(((2021 OR 2.021)) rise vaccines cancer large covid-19)',
#  '(((2021 OR 2.021)) rise vaccines major cancer covid-19)',
#  '(((2021 OR 2.021)) rise vaccines drastic cancer covid-19)',
#  '(((2021 OR 2.021)) rise big cancer vaccines covid-19)',
#  '(((2021 OR 2.021)) vaccines big cancer increase covid-19)',
#  '(((2021 OR 2.021)) diagnoses vaccines cancer surge covid-19)',
#  '(((2021 OR 2.021)) vaccines cancer increase large covid-19)',
#  '(((2021 OR 2.021)) vaccines big cancer jump covid-19)',
#  '(((2021 OR 2.021)) vaccines major increase cancer covid-19)',
#  '(((2021 OR 2.021)) rise vaccines massive cancer covid-19)',
#  '(((2021 OR 2.021)) diagnoses vaccines cancer increase covid-19)',
#  '(((2021 OR 2.021)) rise vaccines cancer huge covid-19)',
#  '(((2021 OR 2.021)) vaccines cancer increase huge covid-19)']

# %% [markdown]
# Concatenating final query

# %%
lexically_enriched_final_query = []
for query_list in lexically_enriched_final_query_list:
  final_query = query_list[0]
  for paraphrase_query in query_list[1:]:
    if len(final_query+' OR '+paraphrase_query) <= 1000:
      final_query = final_query+' OR '+paraphrase_query
  lexically_enriched_final_query.append(final_query)

# %%
lexically_enriched_final_query
# Out:
# ['(((2021 OR 2.021)) spike vaccines huge cancers covid-19) OR (((2021 OR 2.021)) rise cancer tissue vaccines soft covid-19) OR (((2021 OR 2.021)) rise diagnoses cancer vaccinations covid-19) OR (((2021 OR 2.021)) rise significant cancer vaccinations covid-19) OR (((2021 OR 2.021)) rise vaccines cancer diagnosis covid-19) OR (((2021 OR 2.021)) cancer tissue vaccines surge soft covid-19) OR (((2021 OR 2.021)) diagnoses cancer surge vaccinations covid-19) OR (((2021 OR 2.021)) rise vaccines significant cancer covid-19) OR (((2021 OR 2.021)) diagnoses vaccines cancer rise covid-19) OR (((2021 OR 2.021)) rise vaccines cancer large covid-19) OR (((2021 OR 2.021)) rise vaccines major cancer covid-19) OR (((2021 OR 2.021)) rise vaccines drastic cancer covid-19) OR (((2021 OR 2.021)) rise big cancer vaccines covid-19) OR (((2021 OR 2.021)) vaccines big cancer increase covid-19) OR (((2021 OR 2.021)) diagnoses vaccines cancer surge covid-19) OR (((2021 OR 2.021)) vaccines big cancer jump covid-19)',
#  '(marijuana finally (kills OR admits) (cancer OR institute)) OR (cancer research (cause OR confirmed) marijuana) OR (cannabis cancer research (confirmed OR caused) marijuana) OR (cancer smoking research (confirmed OR caused) marijuana) OR (cancer research (confirmed OR caused) marijuana) OR (marijuana center cancer smoking (admitted OR causes)) OR (cancer center (confirmed OR cause) marijuana) OR (finally cigarettes cancer smoking center (admitted OR causes)) OR (cancer center (admitted OR cause) marijuana) OR (marijuana cancer center (confirmed OR causes)) OR (marijuana cancer center (admitted OR causes)) OR (marijuana cancer center (accepted OR causes)) OR (marijuana cancer research (confirmed OR causes)) OR (recently marijuana cancer center (accepted OR causes)) OR (recently marijuana cancer center (confirmed OR causes)) OR (marijuana cancer research (accepted OR causes)) OR (marijuana officially cancer center (confirmed OR causes)) OR (marijuana cancer center (confirmed OR kills))',
#  '(since one cancer heart (started OR died) covid-19) OR (heart existence since one cancer died covid-19) OR (one first cancer heart (died OR introduced) covid-19) OR (since one cancer heart (died OR introduced) covid-19) OR (since one cancer heart (died OR launched) covid-19) OR (one project cancer heart (died OR launched) covid-19) OR (one program heart cancer (died OR launched) covid-19) OR (since lung one heart (died OR introduced) covid-19) OR (one program heart cancer (died OR introduced) covid-19) OR (since lung one heart (died OR launched) covid-19) OR (since one cancer heart (died OR invented) covid-19) OR (lung one disease heart (died OR started) covid-19) OR (since one cancer heart (died OR established) covid-19) OR (since one cancer heart (died OR born) covid-19) OR (one project cancer heart (died OR established) covid-19) OR (one project cancer heart (died OR started) covid-19) OR (one program heart cancer (died OR started) covid-19)',
#  '((80%) countries cancer children (developing OR die OR born)) OR ((("eighty" OR 80)) percent nations cancer year children die) OR ((("eighty" OR 80)) countries percent cancer year children die) OR ((("eighty" OR 80)) percent cancer industrial children (die OR born)) OR ((80%) nations every cancer year children die) OR ((("eighty" OR 80)) percent countries cancer children (die OR born)) OR ((80%) year countries cancer children (die OR estimated)) OR ((80%) countries every cancer year children die) OR ((80%) countries cancer industrial children (die OR born)) OR ((80%) poor countries cancer children (die OR born)) OR ((80%) year cancer children nations (die OR developing)) OR ((80%) year countries cancer children (die OR born)) OR ((80%) year countries cancer children (developing OR die)) OR ((80%) cancer children nations (die OR born OR developing)) OR ((80%) countries cancer children (live OR developing OR die)) OR ((80%) countries cancer children (born OR emerging OR die))',
#  '(hot water sugar cancer lemon (drinking OR cure)) OR (hot water diet cancer lemon change reversed) OR (intake juice sugar cancer lemon (reducing OR drinking)) OR (intake juice sugar cancer lemon (lowering OR drinking)) OR (hot water sugar cancer lemon (reducing OR reversed)) OR (hot water sugar cancer lemon (reducing OR sipping)) OR (hot water sugar cancer lemon (lowering OR reversed)) OR (hot water sugar cancer lemon (lowering OR sipping)) OR (hot water sugar cancer lemon (removing OR reversed)) OR (hot water sugar cancer lemon (prevent OR drink)) OR (intake water sugar cancer lemon (reducing OR drinking)) OR (intake water sugar cancer lemon (lowering OR drinking)) OR (hot juice sugar cancer lemon (reversed OR sipping)) OR (hot juice sugar cancer lemon (reversed OR consuming)) OR (hot water sugar cancer lemon (reducing OR drinking)) OR (hot water sugar cancer lemon (removing OR drinking)) OR (hot water sugar cancer lemon (lowering OR drinking))',
#  '(abortion risk breast cancer increases) OR (hand abortions cancer breast prevention goes) OR (risks pregnancy result breast cancer raised) OR (risks pregnancy result cancer breast rises) OR (risks pregnancy result cancer breast rise) OR (abortions result breast cancer) OR (pregnancy breast cancer result) OR (abortion also breast cancer increased) OR (risk pregnancy cancer breast rises) OR (abortion breast cancer linked) OR (risk abortions cancer breast rises) OR (risk childbirth cancer breast rises) OR (risk pregnancy result cancer breast goes) OR (risks abortion result breast cancer raised) OR (risks abortion result cancer breast elevated) OR (risk pregnancy result cancer breast raised) OR (risk pregnancy result cancer breast rises) OR (risks abortion result cancer breast rises) OR (risks abortion result cancer breast rise) OR (abortion risk cancer breast (goes OR performed)) OR (risk result cancer breast fertility rises) OR (birth risk result cancer breast rises)',
#  '(flu cancer shot (designed OR spread)) OR (humans disease flu shot (supposed OR cause)) OR (people disease flu shot (supposed OR cause)) OR (formation flu tumor shot (supposed OR cause)) OR (lung disease flu shot (supposed OR cause)) OR (flu disease cancerous shot (supposed OR cause)) OR (disease flu shot (supposed OR cause)) OR (vaccine flu cancer (supposed OR cause)) OR (flu cancerous shot (supposed OR cause)) OR (humans cancer shot flu (supposed OR cause)) OR (people cancer shot flu (supposed OR cause)) OR (flu cancer shot children (supposed OR cause)) OR (lung flu cancer shot (supposed OR cause)) OR (flu cancer shot (intended OR cause)) OR (flu cancer shot (shown OR spread)) OR (flu cancer shot (supposed OR help)) OR (flu cancer shot (supposed OR cause)) OR (flu cancer shot (meant OR cause)) OR (disease flu shot (supposed OR spread)) OR (flu cancer shot (expected OR cause)) OR (flu cancer shot (supposed OR promote)) OR (flu cancer shot (believed OR cause))',
#  '((("forty-eight" OR 48) OR 98%) hours dandelion cancer root kill) OR ((98%) less dandelion week tumor root destroy) OR ((98%) less dandelion week cancer root destroy) OR ((("forty-eight" OR 48) OR 98%) hours dandelion tumor root destroy) OR ((("forty-eight" OR 48) OR 98%) hours dandelion cancerous root destroy) OR ((98% OR ("forty-eight" OR 48)) cells dandelion cancer root killed) OR ((("forty-eight" OR 48) OR 98%) hours dandelion cancer root destroy) OR ((("forty-eight" OR 48) OR 98%) cells dandelion cancer root destroy) OR ((98% OR ("forty-eight" OR 48)) hours dandelion tumor root killing) OR ((("forty-eight" OR 48) OR 98%) hours dandelion tumor root kill) OR ((("forty-eight" OR 48) OR 98%) hours dandelion cancer root cure) OR ((98% OR ("forty-eight" OR 48)) hours dandelion cancer root killed) OR ((("forty-eight" OR 48) OR 98%) hours dandelion cancer root killing) OR ((("forty-eight" OR 48) OR 98%) cells dandelion cancer root kill)',
#  '((("forty" OR 40)) molecule cells fungus potency cancer kills) OR ((("forty" OR 40)) molecule cells fungus potency cancer killed) OR ((("forty" OR 40)) cells fungus potency chemical cancer killed) OR ((("forty" OR 40)) cells fungus potency cancer substance killed) OR (molecule himalayan cells fungus cancer (isolated OR killed)) OR (molecule himalayan cells fungus cancer (discovered OR killed)) OR (molecule himalayan cells fungus cancer present killed) OR (himalayan cells fungus chemical cancer (found OR killed)) OR ((("forty" OR 40)) drug cells fungus potency cancer killed) OR ((("forty" OR 40)) molecule cells fungus cancer potent killed) OR ((("forty" OR 40)) compound cells fungus potency cancer killed) OR ((("forty" OR 40)) cells fungus cancer molecule (killing OR killed)) OR ((("forty" OR 40)) protein cells fungus potency cancer killed) OR ((("forty" OR 40)) cells fungus potency chemical cancer destroyed) OR (molecule himalayan cells fungus cancer (found OR killed))',
#  '(tuberculosis malaria cancer kidney aids kill kenya) OR (kidney tuberculosis cancer (killed OR aids OR die) kenya) OR (tuberculosis disease cancer malaria kidney die (kenya OR hiv)) OR (kidney tuberculosis cancer (aids OR died OR die) kenya) OR (tuberculosis malaria cancer kidney aids killed kenya) OR (kidney tuberculosis disease cancer (aids OR die) kenya) OR (kidney tuberculosis disease aids (die OR killed) kenya) OR (kidney tuberculosis disease aids (die OR died) kenya) OR (tuberculosis disease cancer kidney aids die kenya) OR (malaria disease cancer kidney aids die kenya) OR (tuberculosis malaria cancer kidney aids die kenya)',
#  '(vaccine cancer polio cause) OR (vaccination result cancer program) OR (vaccination result cancer process) OR (vaccination program cancer linked) OR (vaccination program cancer caused) OR (fluorovirus cancer linked) OR (tumors polio vaccinations linked) OR (poliovaccines cancer caused) OR (vaccines tumors (linked OR polio)) OR (fluorovirus cancer caused) OR (poliovirus cancer vaccinations linked) OR (poliovaccines cancer linked) OR (poliovaccination cancer linked) OR (cancer (linked OR poliovaccine)) OR (poliovaccination cancer caused) OR (poliovaccine cancer caused) OR (cancer vaccinations linked) OR (result cancer polio vaccinations) OR (vaccines result cancer polio) OR (vaccines cancer polio caused) OR (vaccine flu cancer linked) OR (vaccines cancer polio linked) OR (cancer polio vaccinations linked) OR (vaccines cancer (polio OR linked)) OR (cancer polio vaccinations caused) OR (product cancer polio vaccinations) OR (vaccines cancer breast (polio OR linked))',
#  '(body day every hydrogen cancer peroxide rubbing) OR (body day every hydrogen solution peroxide raging) OR (day every hydrogen cancer peroxide (raging OR used)) OR (body day every hydrogen peroxide (rustling OR applied)) OR (body day every hydrogen peroxide (applied OR raging)) OR (day every hydrogen cancer peroxide (used OR rustling)) OR (day every hydrogen cancer peroxide (used OR rusting)) OR (body day every hydrogen peroxide (injected OR raging)) OR (body day rusty every hydrogen peroxide injected) OR (body day every hydrogen cancer peroxide coating) OR (body day rusty hydrogen cancer peroxide coating) OR (body day cancer peroxide coating rusting hydrogen) OR (body day hydrogen cancer peroxide (coating OR cure)) OR (body day every hydrogen coats peroxide raging) OR (body day every hydrogen peroxide (raging OR coat)) OR (body day every hydrogen coats peroxide rustling) OR (body day every hydrogen peroxide (raging OR reaches)) OR (body day every hydrogen coats peroxide rusting)',
#  '(antiperspirant breast cancer causes) OR (antiperspirants result breast cancer) OR (antiperspirants breast cancer caused) OR (antiperspirants breast cancer linked) OR (antiperspirants breast cancer triggered) OR (antiperspirants breast cancer attributed) OR (antiperspirants breast cancer induced) OR (antiperspirants breast cancer associated) OR (antiperspirants breast cancer related) OR (breast antibiotics cancer caused) OR (therapy antiperspirant drug breast cancer caused) OR (antiperspirant result breast cancer) OR (antiperspirant breast cancer caused) OR (antiperspirant drug breast cancer use caused) OR (antiperspirant breast cancer drug caused) OR (breast cancer use product antiperspirant) OR (product antiperspirant cancer breast) OR (therapy cancer breast product antiperspirant) OR (antiperspirant cancer drugs breast caused) OR (result cancer use breast antiperspirant) OR (antiperspirant cancer use breast caused) OR (therapy result cancer breast antiperspirant)',
#  '(((10 OR "ten")) men sexual partners cancer women risk) OR (ten sexual risk partners cancer female rises) OR (ten sexual risk partners cancer female raised) OR (((10 OR "ten")) sexual risk partners cancer female rises) OR (ten men sexual partners cancer women risk) OR (ten sexual breast cancer partners women risk) OR (ten sexual women risk partners cancer raises) OR (ten men partners cancer intimate women risk) OR (((10 OR "ten")) sexual women risk partners cancer raises) OR (((10 OR "ten")) men cancer partners intimate women risk) OR (((10 OR "ten")) sexual cancer breast partners women risk)',
#  '(biopsy cancer (spread OR getting OR makes)) OR (formation biopsy tumor help) OR (biopsy cancer first step spreading) OR (biopsy risk cancer increase) OR (transmission biopsy cancer help) OR (biopsy cancer progression help) OR (biopsy result cancer) OR (risk biopsy cancer help) OR (product biopsy cancer) OR (formation biopsy cancer help) OR (propagation biopsy cancer help) OR (biopsy cancer dissemination help) OR (risk biopsy cancer increases) OR (results biopsy cancer progression receiving) OR (biopsy cancer prevention help) OR (results biopsy cancer (spreading OR receiving)) OR (results biopsy cancer progression) OR (results biopsy cancer spreading) OR (results biopsy cancer development) OR (biopsy cancer help) OR (biopsy risk cancer determine) OR (risk results biopsy cancer) OR (spread biopsy cancer aid) OR (biopsy spread cancer help) OR (biopsy cancer (causes OR spread)) OR (biopsy spread cancer aids) OR (biopsy cancer (cause OR spread)) OR (biopsy cancer spread)',
#  '(sugar cancer (grow OR eating OR causes)) OR (cells sugar diet result cancer increase) OR (sugar diet result cancer rise intake) OR (cells sugar diet result cancer rise) OR (sugar diet result cancer rise) OR (intake sugar result cancer rise) OR (intake cells sugar cancer also affected) OR (sugar diet cancer result intake) OR (sugar diet cancer result) OR (intake sugar result cancer) OR (cells sugar result cancer (eating OR increase)) OR (cells sugar result cancer (eating OR rise)) OR (rates sugar result cancer (eating OR rise)) OR (cells sugar result cancer (eating OR expand)) OR (cells sugar result cancer (eating OR develop)) OR (cells sugar diet result cancer grow) OR (sugar result cancer (eating OR rise)) OR (sugar result cancer (eating OR risen)) OR (sugar result cancer (eating OR develop)) OR (sugar diet cancer result grow) OR (sugar result cancer (rises OR eating)) OR (cells sugar cancer also (eating OR affected)) OR (cells sugar cancer (grow OR consume))',
#  '(surgery tumor solid need) OR (surgery tumor solid needing) OR (surgery tumor solid required) OR (surgery tumors solid need) OR (surgery tumor chemotherapy solid require) OR (surgery tumor solid require) OR (surgery tumor solid) OR (tumour surgery solid need) OR (surgery tumor solid (may OR require)) OR (surgery cancer solid need) OR (surgery tumor solid don) OR (surgery tumor chemotherapy solid need) OR (solid surgery tumor radiation need) OR (surgery tumor solid (may OR need)) OR (clear surgery tumor need) OR (surgery tumor likely solid need) OR (surgery tumor solid (would OR need)) OR (strong surgery tumor need) OR (surgery tumor firm need) OR (surgery tumor solid need don) OR (healthy surgery tumor need) OR (surgery tumor stable need) OR (surgery intact tumor need) OR (surgery tumor large need)',
#  '(skin cancer blind color) OR (skin disease cancer colorblind) OR (skin phenomenon cancer colorblind) OR (colorblindness cancer skin caused) OR (condition skin cancer colorblind) OR (skin colorblind primarily cancer) OR (skin cancer colorblind mainly) OR (colorblind cancer skin) OR (skin colorblind cancer mostly) OR (skin cancer colorblind also) OR (skin cancer blind color described) OR (skin cancer) OR (skin cancer blindness color caused) OR (skin cancer blindness color characterized) OR (pigment skin disease cancer blind) OR (skin blind result cancer color going) OR (skin cancer blindness color) OR (skin colour cancer primarily blind) OR (patients skin cancer color blind) OR (skin cancer colour mainly blind) OR (skin disease cancer color epidemic blind) OR (skin disease cancer color blind) OR (skin blind cancer color also known) OR (skin cancer blind color seen) OR (skin cancer blind largely) OR (skin phenomenon cancer color blind) OR (condition skin cancer color blind)',
#  '(side bad always effects chemotherapy) OR (never chemotherapy adverse) OR (adverse side effects chemotherapy also known) OR (negative side effects chemotherapy also known) OR (adverse effects side chemotherapy also associated) OR (effect negative side chemotherapy children) OR (always chemotherapy negative) OR (always chemotherapy adverse) OR (chemotherapy side effect negative) OR (side chemotherapy effects adverse known) OR (side chemotherapy effects negative known) OR (effects history adverse side chemotherapy) OR (always effect negative side chemotherapy) OR (effects adverse side chemotherapy never) OR (effects negative side chemotherapy never) OR (effects inevitably adverse side chemotherapy) OR (effects adverse side also chemotherapy) OR (effects chemotherapy side) OR (effects side always negative chemotherapie) OR (side negative effects also chemotherapy) OR (side always negative effects chemotherapy) OR (side chemotherapy effects adverse) OR (bad always chemotherapy)',
#  '(lump always breast cancer) OR (breast also cancer sign) OR (lump breast cancer usually indicates) OR (lump also breast cancer indicates) OR (lump breast cancer indicates) OR (always breast cancer present lumps) OR (lump likely breast cancer) OR (lump breast cancer sure) OR (breast cancer lump almost certainly) OR (breasts cancer breast usually lump caused) OR (lump always breast cancer indicates) OR (lump breast cancer usually) OR (lump inevitably breast cancer) OR (lump definitely breast cancer) OR (lump breast cancer probably) OR (lump obviously breast cancer) OR (lump breast cancer clearly) OR (lump breast cancer usually caused) OR (result breast cancer lump also) OR (responsible breast cancer lump also) OR (often breast cancer lump caused) OR (lump always cancer breast means) OR (always breast cancer lump almost) OR (often breast cancer lump) OR (lump also breast cancer) OR (always breast tumor cancer) OR (normally breast cancer lump) OR (lump always breast cancer related)',
#  '(treatment women cancer pregnant get) OR (unlikely survivors cancer breast treatment receive) OR (chemotherapy unlikely women pregnant receive) OR (chemotherapy women unable pregnant receive) OR (women pregnancy early unable cancer treatment receive) OR (therapy pregnant women unable cancer receive) OR (therapy pregnant unlikely women cancer receive) OR (therapy pregnant women unable cancer obtain) OR (women pregnancy unable cancer treatment receive) OR (women pregnancy unable cancer treatment obtain) OR (treatment women unable cancer (receive OR breastfeeding)) OR (treatment women unable cancer (obtain OR breastfeeding)) OR (pregnant women unable cancer care receive) OR (therapy cancer pregnant women eligible) OR (unlikely treatment women cancer (receive OR breastfeeding)) OR (unlikely women pregnancy cancer treatment receive) OR (pregnant unlikely women cancer care receive) OR (unlikely survivors cancer breast treatment get) OR (therapy women cancer pregnant receive)',
#  '(chemotherapy back hair never grow) OR (since chemotherapy hair never (treated OR recover)) OR (since hair never recover) OR (since chemotherapy hair never (recover OR undergoing)) OR (since chemotherapy hair never (recover OR receiving)) OR (since chemotherapy hair never recover) OR (hair chemotherapy recover) OR (hair chemotherapy never recover) OR (chemotherapy hair never (would OR recover)) OR (chemotherapy hair never (recover OR following)) OR (chemotherapy hair never (treated OR recover)) OR (since chemotherapy hair never (induced OR recover)) OR (chemotherapy treatment hair never recover) OR (chemotherapy normal hair never return) OR (chemotherapy hair never (undergoing OR recover)) OR (chemotherapy hair never (receiving OR recover)) OR (chemotherapy loss hair never recover) OR (fully chemotherapy hair never recover) OR (chemotherapy hair never (shampooing OR recover)) OR (therapy hair since chemotherapy never recover) OR (chemotherapy completely hair never recover)',
#  '(back always cancer come) OR (cancer never return (united OR states)) OR (also cancer return (united OR states)) OR (cancer never (return OR ask)) OR (cancer never (return OR look)) OR (cancer never return) OR (cancer never (return OR comes)) OR (cancer never control) OR (unless cancer never (return OR wait)) OR (present cancer longer) OR (us always tumors return) OR (cancer common longer) OR (always cancerous) OR (almost certainly cancer return) OR (likely cancer return) OR (always) OR (breast cancer never return) OR (certainly cancer return) OR (definitely cancer return) OR (cancer unquestionably return) OR (cancer never recover) OR (always tumors return) OR (cancer probably return) OR (also cancer return) OR (undoubtedly cancer return) OR (eventually cancer return) OR (still cancer exist) OR (cancer surely return) OR (always cancer return (united OR states)) OR (always cancer return (united OR kingdom)) OR (always cancer (return OR ask)) OR (always cancer (return OR look))',
#  '(patients treatments unusual oncologists (want OR trying) don) OR (therapies oncologists unlikely experimental patients interested according) OR (therapies oncologists experimental patients keen undergoing) OR (therapies new oncologists patients keen undergoing) OR (therapies oncologists experimental patients interested undergoing) OR (therapies new oncologists patients interested undergoing) OR (therapies oncologists patients keen novel receiving) OR (therapies oncologists patients novel interested receiving) OR (therapies unlikely patients unusual drugs (receiving OR trying)) OR (therapies strange unlikely patients unusual drugs trying) OR (therapies oncologists unlikely patients unusual interested seeking) OR (therapies oncologists unlikely patients unusual interested receiving) OR (patients unusual drugs oncologists (concerned OR according)) OR (therapies new oncologists patients keen trying) OR (strange oncologists patients keen drugs trying)',
#  '(phones cancer cause) OR (smartphones cancerous) OR (product smartphones cancer) OR (smartphones cancer linked) OR (devices cell phones) OR (cells phones cell) OR (smartphones cancer causing) OR (telephones cancer causing) OR (devices phones) OR (cells phones) OR (smartphones cancer lead) OR (phones cancerous cell) OR (phones cell) OR (phones cancerous causing) OR (phones tumors causing) OR (phones cancerous) OR (phones) OR (phones carcinogenetic) OR (product phones cancer cell) OR (phones source cancer cell) OR (responsible cancer cell also phones) OR (product phones cancer) OR (carriers phones cancer cell) OR (phones source cancer) OR (phones cancer cell linked) OR (responsible also cancer phones) OR (responsible phones cancer cell) OR (phones cancer root) OR (cause smartphones cancer) OR (phones cancer cell associated) OR (phones cancer causes known) OR (phones cancer cell causing) OR (phones cancer linked) OR (responsible phones cancer) OR (phones cancer associated)',
#  '(cancer foods (cause OR eating OR burnt)) OR (burningt cancer foods caused) OR (result cancer foods (eating OR burned)) OR (result cancer foods eating burnedt) OR (cancer foods (caused OR eating) burnedt) OR (result cancer foods (eating OR cooked)) OR (cancer foods (caused OR eating OR burned)) OR (food result cancer (eating OR burnt)) OR (people cancer foods (eat OR burnt OR develop)) OR (cancer foods (linked OR eating OR burned)) OR (cancer foods (linked OR eating) burnedt) OR (carcinogenesis foods (linked OR eating OR burnt)) OR (cancer foods (linked OR consuming OR burnt)) OR (foods (linked OR eating OR burnt) carcinos) OR (food cancer (linked OR eating OR burnt)) OR (cancer foods (linked OR eating OR cooked)) OR (food cancer (caused OR eating OR burnt)) OR (cancer foods raw (linked OR eating)) OR (people cancer foods (eat OR burnt)) OR (cancer foods (associated OR eating OR burned)) OR (cancer foods (caused OR eating OR cooked)) OR (cause cancer carcinogenic roasting foods)',
#  '(bottles cancer plastic containers cause) OR (carcinogenic bottles plastic cans) OR (bottles plastic cans) OR (bottles cancerous plastic cans) OR (carcinogenic tubs bottles plastic) OR (responsible cancer plastic cans also bottles) OR (cancer plastic cans product bottles) OR (bottles cancer plastic cans contaminated) OR (responsible cancer plastic cans bottles) OR (susceptible cancer plastic cans bottles) OR (cancer harmful cans plastic bottles) OR (cancer infectious cans plastic bottles) OR (tubs bottles cancer plastic contaminated) OR (bottles cancer plastic cans linked) OR (bottles cancer plastic cans causing) OR (bottles cancer plastic cans lead) OR (tubs bottles cancer plastic causing) OR (jars bottles cancer plastic lead) OR (jars bottles cancer plastic causing) OR (carcinogenic bottles plastic containers) OR (bottles cancerous plastic containers) OR (bottles cancer plastic cans contain) OR (bottles plastic containers) OR (responsible cancer plastic containers also bottles)',
#  '(sweeteners artificial cancer cause) OR (sweeteners artificial cancerous effects) OR (sweeteners artificial activity cancerous) OR (sweeteners artificial carcinogenetic) OR (carcinogenic sweeteners artificial) OR (sweeteners artificial carcinogens) OR (sweeteners artificial cancerous) OR (sweeteners artificial carcinogenous) OR (sweeteners artificial carcinogenics) OR (sweeteners artificial cancerous make) OR (sweeteners artificial cancer linked) OR (sweeteners risk artificial cancer raise) OR (responsible artificial cancer sweeteners also) OR (sweeteners artificial cancer responsible) OR (sweeteners risk artificial cancer increase) OR (sweeteners artificial cancer associated) OR (sweeteners artificial cancerous growth cause) OR (artificial tissue cancerous growth sweeteners cause) OR (sweeteners formation artificial tumor cause) OR (sweeteners artificial cancer harmful) OR (artificial formation cancerous tumor sweeteners cause) OR (sweeteners artificial cancer lead)',
#  '(cancer foods genetically (modified OR cause)) OR (modification genetic foods disease cancer linked) OR (cancer result modification genetic foods) OR (modification cancer genetic foods caused) OR (result cancer diets genetically altered) OR (diet cancer genetically altered) OR (disease cancer foods genetically (linked OR altered)) OR (disease cancer foods genetically (associated OR altered)) OR (disease cancer foods genetically (caused OR altered)) OR (result cancer foods genetically altered) OR (result cancer diets genetically modified) OR (cancer foods genetically (altered OR caused)) OR (product cancer foods genetically altered) OR (cancer foods genetically (altered OR linked)) OR (food result cancer genetically modified) OR (byproduct cancer foods genetically altered) OR (foods tumors genetically (linked OR modified)) OR (genetically foods tumors (associated OR modified)) OR (cancer foods genetically (associated OR altered)) OR (cancer diets genetically (linked OR modified))',
#  '(pesticides herbicides risk foods cancer farms eating) OR (pesticides herbicides risk vegetables cancer farms growing) OR (pesticides herbicides food risk cancer farms growing) OR (fruits pesticides herbicides risk cancer farms growing) OR (herbicides risk foods cancer farms pesticide growing) OR (pesticides herbicides foods cancer farms children growing) OR (pesticides herbicides risk foods cancer farms growing) OR (pesticides herbicides food risk cancer farms grown) OR (pesticides herbicides vegetables cancer farms (grown OR growing)) OR (pesticides herbicides foods cancer farms (eating OR raised))',
#  '(cause toiletries makeup cancer use) OR (makeup toiletries result cancer using) OR (makeup toiletries disease celiac caused) OR (makeup toiletries cancers caused) OR (makeup toiletries tumors used) OR (makeup coughing toiletries caused) OR (toxic toiletries makeup infections caused) OR (makeup toiletries disease celiac linked) OR (makeup toiletries tumors caused) OR (makeup toiletries coughs caused) OR (makeup coughing toiletries linked) OR (makeup toiletries tumors associated) OR (makeup toiletries cancer (using OR get)) OR (makeup toiletries breast cancer caused) OR (makeup toiletries result cancer) OR (makeup toiletries cancer caused) OR (makeup toiletries cancer (using OR caused)) OR (makeup toiletries cancer (linked OR using)) OR (makeup toiletries cancer linked) OR (makeup toiletries cancer (use OR get)) OR (makeup toiletries cancer associated) OR (makeup toiletries cancer use lead) OR (makeup toiletries cancer use result) OR (makeup toiletries cancer use common make)',
#  '(dairy cancer products milk cause) OR (result breast cancer products dairy) OR (result cancer products milk cheese) OR (result cancer products breastfeeding dairy) OR (result cancer products dairy meat) OR (milk tumors products common dairy associated) OR (byproduct cancer products milk cheese) OR (dairy tumors products milk associated) OR (dairy result cancer products) OR (common milk products dairy tumors) OR (responsible cancer breast products dairy) OR (cheese cancer products milk linked) OR (dairy tumors products milk linked) OR (cheese cancer products milk associated) OR (cheese cancer products milk caused) OR (dairy breast cancer products linked) OR (dairy cancer products linked) OR (cancer problem milk common products dairy) OR (milk result cancer products dairy drinking) OR (result cancer products milk dairy) OR (result cancer products milk dairy also) OR (result breast products milk cancer dairy) OR (cancer products milk common reaction dairy)',
#  '(stress cancer cause) OR (stress formation cancerous tumor causes) OR (stress cancerous tumors causes) OR (cells stress cancerous causes) OR (product stress cancer) OR (stress cancer contributor) OR (stress trigger cancer) OR (stress cancer attributed) OR (stress cancer root) OR (stress catalyst cancer) OR (stress source cancer) OR (stress formation cancerous tumor cause) OR (stress result cancer) OR (stress cancer risk) OR (stress cancer linked) OR (stress killer cancer) OR (responsible stress cancer) OR (stress cancer blamed) OR (tumour cancerous formation stress cause) OR (stress cancerous growth tissue cause) OR (stress cancer lead) OR (stress cancerous tumors cause) OR (stress cancer children causes) OR (stress tumours cancerous cause) OR (stress women cancer causes) OR (often stress cancer leads) OR (stress cancerous growth cause) OR (stress formation tumor cause) OR (cells stress cancerous cause) OR (stress cancerous changes cause) OR (stress cancer leads)',
#  '(power cancer lines cause) OR (formation power tumor lines lead) OR (power cancerous lines known) OR (power cancerous lines) OR (carcinogenic power lines) OR (power lines) OR (power carcinogenetic lines) OR (product power cancer lines) OR (source power cancer lines) OR (power cancer lines caused) OR (responsible power cancer lines also) OR (power cancer causes lines) OR (power cancer causes lines known) OR (responsible power cancer lines) OR (power cancer lines linked) OR (power cancer lines lead) OR (power cancer lines associated) OR (formation power tumor lines cause) OR (power cancer common lines) OR (power cancerous growth lines cause) OR (power cancer lines known) OR (power cancer lines related) OR (power cancer lines causing) OR (power cancer lines result) OR (electric cancer lines cause) OR (power cancer lines contribute) OR (power cancer cords cause) OR (cancer lines cause stroma) OR (cancer lines (charging OR cause)) OR (electricity cancer lines cause) OR (power cancer lines)',
#  '(surgery cancer (spread OR causes)) OR (product treatment cancer center) OR (treatment result cancer center) OR (result cancer chemotherapy) OR (therapy result cancer chemotherapy) OR (therapy product breast cancer) OR (also result cancer chemotherapy) OR (result cancer diagnosis) OR (product cancer diagnosis) OR (product treatment breast cancer) OR (product therapy cancer chemotherapy) OR (product breast cancer) OR (treatment result cancer) OR (product therapy cancer) OR (product cancer chemotherapy) OR (product treatment cancer) OR (therapy result cancer) OR (product cancer) OR (form cancer) OR (disease cancer chemotherapy spread) OR (chemotherapy also cancer tumors spread) OR (disease cancer spread) OR (product surgery breast cancer) OR (product lung surgery cancer) OR (surgery breast cancer result) OR (product spread cancer) OR (spread result cancer) OR (also treatment cancer tumors linked) OR (product surgery cancer) OR (also cancer chemotherapy spread) OR (surgery result cancer)',
#  '(bra breast cancer (wearing OR causes)) OR (cancer braces breast (wearing OR caused)) OR (bra cancer (wearing OR caused) reast) OR (bra women breast cancer common wearing) OR (bra breast cancer (caused OR wearing)) OR (bra breast cancer (triggered OR wearing)) OR (bra breast cancer (attributed OR wearing)) OR (bra result cancer breast wearing) OR (primarily bra breast cancer (caused OR wearing)) OR (bra breast cancer mainly (caused OR wearing)) OR (bra breast cancer (induced OR wearing)) OR (bra breast cancer largely (caused OR wearing)) OR (bra breast cancer (related OR wearing)) OR (bra mainly breast cancer due wearing) OR (bra breast cancer largely (related OR wearing)) OR (bra breast cancer common wearing) OR (bra breast cancer (may OR caused OR wearing)) OR (bra breast cancer (linked OR wearing)) OR (bra breast cancer (wearing OR exacerbated)) OR (bra breast cancer (wearing OR associated)) OR (bra breast cancer (wearing OR tied)) OR (bra breast cancer (wearing OR increased))',
#  '(herbal cancer medicines cure) OR (herbal cancer drugs (shown OR prevent)) OR (herbal cancer medications (shown OR prevent)) OR (herbal cancer drugs (shown OR treat)) OR (herbal cancer drugs (shown OR reduce)) OR (remedies cancer herbal (shown OR prevent)) OR (herbal cancer medications (shown OR treat)) OR (herbal cancer medications (shown OR reduce)) OR (herbal cancer drugs (shown OR fight)) OR (herbal cancerous drugs tumors cause) OR (herbal cancer drugs (used OR treat)) OR (herbal cancer medications (used OR treat)) OR (herbal cancer medicines (shown OR prevent)) OR (remedies cancer herbal (used OR treat)) OR (herbal cancer products (used OR treat)) OR (herbal cancer medicines (shown OR treat)) OR (herbal cancer drugs (shown OR cure)) OR (treatment herbal cancer drugs help) OR (herbal cancer drugs help) OR (herbal cancer medications help) OR (also herbal cancer drugs treat) OR (prevention herbal cancer drugs cause) OR (herbal cancer remedies help) OR (herbal drugs cancer treat)',
#  '(cancer cure) OR (curable tumors) OR (cancer drugs (treat OR used)) OR (cancer available cure) OR (cancer curable) OR (treatment cancer found) OR (way cancer (prevent OR occurring)) OR (cancer curable thing) OR (thing cure) OR (cures cancer curable) OR (cancer cure found) OR (treatment cancer curable) OR (treatment cancer thing) OR (treatment cancer (united OR states)) OR (vaccine cancer thing) OR (cancer thing cure) OR (medicine cancer thing) OR (cures cancer) OR (cancer curable cure) OR (treatment cancer drug) OR (cancer cure (united OR states)) OR (cancer drug cure) OR (cancer cure (united OR kingdom)) OR (treatment cancer) OR (cancer drug) OR (cancer time cure) OR (moment cancer cure) OR (medicine cancer) OR (besides cancer chemotherapy cure) OR (available cancer currently cure) OR (cancer currently cure) OR (unfortunately cancer cure) OR (today cancer cure)',
#  '(lung cancer smokers develop) OR (ones cancer users nicotine lung) OR (lung sufferers cancer people smoke) OR (lung sufferers cancer smoke) OR (product lung cancer smoking) OR (experts cancer smokers lung (according OR get)) OR (lung people cancer smoke) OR (lung cancer smoke) OR (lung prone disease smokers) OR (lung exclusive smokers cancer) OR (lung cancer smokers limited) OR (lung people cancer (vaping OR get)) OR (lung cancer smokers restricted) OR (cigarette lung cancer users get) OR (lung cancer smokers get) OR (lung people cancer (smoking OR get)) OR (smokers lung ones cancer experience) OR (smokers lung ones cancer get) OR (ones cancer smokers lung) OR (lung smokeers cancer get) OR (lung disease smokers get) OR (lung cancer get) OR (lung cancer) OR (lung smokeers cancer) OR (product lung cancer smokers) OR (experts cancer smokers lung (according OR develop)) OR (lung prone cancer smokers) OR (lung cancer smokers affected) OR (susceptible lung cancer smokers)',
#  '(way cancer risk lung reduce) OR (country risks lung way cancer minimize) OR (threat lung way cancer region minimize) OR (risks lung way cancer region minimize) OR (country lung chance way cancer minimize) OR (area threat lung way cancer minimize) OR (risks area lung way cancer minimize) OR (country threat lung way cancer minimize) OR (lung risk way cancer region minimize) OR (country lung risk way cancer minimize) OR (area lung risk way cancer minimize) OR (regard lung risk way cancer minimize) OR (lung risk way cancer population minimize) OR (lung risk way cancer period minimize) OR (lung risk patients way cancer minimize) OR (lung risk way cancer age minimize) OR (form lung risk way cancer minimize) OR (lung risk way cancer region lower) OR (lung risk way cancer world minimize) OR (angle lung risk way cancer minimize) OR (lung risk way cancer present minimize) OR (risks way cancer lung minimize) OR (way cancer threat lung minimize) OR (way danger cancer lung minimize)',
#  '(adults older lung cancer nly develop) OR (disease among cancer common lung seniors) OR (disease cancer common lung seniors) OR (condition cancer common lung seniors) OR (condition among cancer common lung seniors) OR (elderly population cancer lung) OR (among cancer problem common lung seniors) OR (patients lung cancer elderly) OR (citizens among cancer lung senior mainly) OR (lung cancer seniors) OR (lung adults cancer first suffer) OR (adults disease among cancer common lung) OR (elderly adults cancer lung majority) OR (vulnerable lung adults cancer) OR (lung adults cancer majority) OR (lung adults cancer old suffer) OR (lung adults cancer old) OR (lung adults cancer old get) OR (lung adults cancer senior) OR (lung adults cancer senior get) OR (lung adults cancer elderly) OR (lung adults cancer old experience) OR (elderly adults cancer lung get) OR (elderly adults cancer lung experience) OR (adults cancer older lung majority) OR (adults older lung first cancer experience)',
#  '(city polluted lung risk worse cancer smoking) OR (area polluted lung risk cancer (raises OR living)) OR (area polluted lung risk cancer (smoking OR living)) OR (city polluted lung risk cancer (raise OR living)) OR (city lung risk cancer crowded smoking living) OR (lung risk cancer crowded smoking neighborhood living) OR (city polluted lung risk cancer (raises OR living)) OR (city polluted lung risk cancer (smoking OR living)) OR (city harmful polluted lung cancer prevention living) OR (city cancer harmful crowded smoking lung risk) OR (harmful polluted lung risk cancer smoking living) OR (harmful polluted lung cancer smoking neighborhood living) OR (city lung populated risk cancer smoking living) OR (detrimental polluted lung cancer smoking neighborhood living) OR (detrimental polluted lung risk cancer smoking living) OR (city harmful lung populated cancer smoking living) OR (harmful polluted lung cancer smoking prevention living) OR (city lung worse crowded cancer prevention living)',
#  '(lung risk cancer powder (increases OR breathing) talcum) OR (bronchial lung risk exposure result cancer rises) OR (bronchial lung risk result cancer breathing rises) OR (lung danger cancer powder (smoking OR rises) talcum) OR (talcum respiratory lung risk powder cancer raises) OR (lung risk cancer powder (smoking OR rises) talcum) OR (lung risk cancer powder rises (talcum OR intake)) OR (talcum lung risk powder cancer smuggling raise) OR (cigarette lung risk powder cancer raise talcum) OR (talcum lung risk powder cancer vaporization raise) OR (talcum lung risk powder cancer puff raise) OR (talcum intake lung risk powder cancer rises) OR (talcum lung risk powder cancer vaporization raises) OR (talcum breather lung risk powder cancer raises) OR (talcum lung risk powder cancer (inhaling OR raises)) OR (talcum lung risk powder cancer breathing rises) OR (lung danger cancer powder (breathing OR rises) talcum) OR (lung risk cancer powder (breathing OR rises) talcum)',
#  '(lung always cancer symptoms shows) OR (lung disease cancer common (united OR states)) OR (signs disease cancer lung chronic) OR (disease cancer fatal lung chronic) OR (disease cancer lung chronic cure) OR (respiratory lung disease cancer common problems causes) OR (respiratory lung disease cancer common distress causes) OR (lung people disease cancer chronic affects) OR (cause respiratory disease cancer common lung) OR (everyone lung disease cancer chronic affects) OR (cause disease cancer common lung) OR (lung cancer indefinitely tendency develop) OR (disease cancer also lung sign) OR (lung disease cancer common causes) OR (lung disease cancer chronic) OR (lung signs cancer) OR (lung disease cancer common) OR (cause lung cancer common) OR (condition lung cancer common) OR (problem lung cancer common) OR (form lung cancer) OR (also signs cancer lung showing) OR (lung asymptomatic cancer never) OR (disease cancer lung symptoms chronic) OR (lung symptoms disease cancer chronic causes)',
#  '(lung always cancer terminal) OR (lung cancers terminal) OR (lung cases cancer terminal) OR (lung cancer fatal usually) OR (lung cancer fatal never) OR (lung almost cancer fatal) OR (lung cancer fatal generally) OR (lung cancer fatal also) OR (lung cancer fatal) OR (often lung cancer fatal) OR (normally lung cancer fatal) OR (virtually lung cancer fatal) OR (lung fatal cancer rarely) OR (lung cancer incurable also) OR (lung fatal essentially cancer) OR (lung invariably cancer fatal) OR (lung practically cancer fatal) OR (lung cancer unquestionable) OR (unavoidable cancer lung) OR (lung likely cancer terminal) OR (nature cancer also lung terminal) OR (always cancer lung almost fatal) OR (lung disease cancer terminal) OR (lung illness cancer terminal) OR (lung always cancer fatal) OR (terminal lung cancer also) OR (lung still cancer terminal) OR (lung cancer usually terminal) OR (lung definitely cancer terminal) OR (lung certainly cancer terminal) OR (terminal lung cancer already)',
#  '(lung supplements cancer antioxidant protect) OR (antioxidant cancer drugs also) OR (antioxidant lung risk cancer drugs (shown OR reduce)) OR (antioxidant lung risk cancer drugs (used OR reduce)) OR (antioxidant medications lung risk cancer (used OR reduce)) OR (antioxidant lung cancer drugs prevention (used OR prevent)) OR (antioxidant lung cancer also drugs (used OR fight)) OR (antioxidant lung cancer drugs prevention effect may) OR (risks antioxidant lung cancer drugs (used OR reduce)) OR (risks antioxidant lung cancer drugs (shown OR reduce)) OR (antioxidant cancer drugs lung (used OR fight)) OR (antioxidant cancer medications lung (used OR fight)) OR (antioxidant cancer drugs lung (used OR prevent)) OR (antioxidant cancer medications lung (used OR prevent)) OR (antioxidant cancer drugs lung (used OR treat)) OR (antioxidant lung cancer helpful also drugs preventing) OR (antioxidant cancer medications lung (used OR treat)) OR (tablets antioxidant cancer lung (fight OR used))',
#  '(fertilization risk cancer breast vitro increases) OR (risk result cancer breast fertilisation vitro rises) OR (fertilization risk result cancer breast vitro rises) OR (fertilization risk breast cancer also vitro raised) OR (fertilization risk breast cancer also vitro increased) OR (fertilization risk cancer breast also vitro elevated) OR (fertilization risk cancer breast vitro elevated) OR (fertilization risk breast cancer vitro increased) OR (fertilization risk breast cancer vitro raised) OR (fertilization risk breast cancer vitro goes) OR (fertilization risk cancer breast indefinitely vitro risen) OR (fertilization risk result cancer breast vitro goes) OR (fertilization risk result cancer breast vitro rise) OR (fertilization risk cancer breast vitro rises) OR (fertilization risk cancer breast vitro risen) OR (fertilization chance breast cancer vitro raises) OR (increases cancer fertilization breast result risk vitro) OR (fertilization since risk cancer breast vitro risen)',
#  '(adults breast cancer older happens) OR (citizens among cancer breast rare senior) OR (breast cancer age women exclusive) OR (citizens breast cancer exclusive senior) OR (senior citizens breast cancer limited) OR (elderly breast cancer people exclusive) OR (elderly people breast cancer limited) OR (senior citizens breast cancer restricted) OR (breast cancer people exclusive old) OR (elderly people breast cancer restricted) OR (breast seniors cancer exclusive) OR (elderly people breast cancer affects) OR (breast seniors cancer limited) OR (breast elders cancer exclusive) OR (breast seniors cancer restricted) OR (females breast exclusive cancer) OR (breast cancer seniors affects) OR (breast cancer older people exclusive) OR (people cancer older breast limited) OR (people cancer older breast restricted) OR (cancer breast older women exclusive) OR (women cancer older breast limited) OR (adults cancer breast exclusive old) OR (unique cancer older breast people)',
#  '(risk nipple piercings cancer breast increase) OR (risks result nipple cancer breast piercings rise) OR (risks rise nipple piercings cancer breast) OR (risk piercing result nipple cancer breast rises) OR (risks nipple piercings cancer breast risen) OR (risks nipple piercings cancer breast also elevated) OR (risks thanks nipple cancer breast piercings risen) OR (risks nipple piercings cancer breast increased) OR (risks nipple breast piercings cancer raised) OR (risks nipple piercings cancer breast elevated) OR (risk breast piercings cancer nitpickle heightened) OR (risks thanks nipple piercings cancer breast rise) OR (nifty risk cancer piercings breast raised) OR (nifty risk thanks cancer piercings breast rises) OR (risk cancer piercings breast nitpickle rises) OR (increases cancer piercings breast nitpickle risk) OR (nifty risk cancer piercings breast rises) OR (increases cancer piercings breast result nipple risk) OR (risk thanks nipple cancer piercings breast rises)',
#  '(men cancer breast get) OR (counterpart male breast cancer) OR (among cancer problem breast women) OR (among cancer males common breast) OR (male issue breast cancer) OR (men women breast cancer affect) OR (male breast cancer problem) OR (condition male breast cancer) OR (among cancer males breast exist) OR (breast cancer males appear) OR (breast cancer males occur) OR (among cancer males breast occur) OR (among cancer males breast happen) OR (breast cancer males exist) OR (male disease breast cancer) OR (women breast cancer affect) OR (breast cancer males affect) OR (cancer breast appear) OR (patients cancer breast affect) OR (cancer breast occur) OR (cancer breast affect) OR (men among cancer problem breast) OR (men cancer problem breast) OR (men among cancer breast epidemic) OR (men disease among cancer breast) OR (men breast cancer occur) OR (men breast cancer appear) OR (men breast cancer happen) OR (men among cancer common breast) OR (men breast cancer cause)',
#  '(breast cancer mammograms (spread OR cause)) OR (product breast cancer mammograms carried) OR (product mammograms breast cancer also transmitted) OR (product breast cancer mammograms transmitted) OR (product breast cancer mammograms spreading) OR (mammograms result cancer breast spreading) OR (product mammograms breast cancer also spread) OR (product breast cancer mammograms spread) OR (result cancer mammograms breast spread) OR (rise breast cancer also mammograms) OR (mammograms result cancer breast risen) OR (mammograms result cancer breast) OR (breast cancer mammograms carried) OR (result cancer breast also mammograms) OR (tandem breast cancer mammograms risen) OR (rise cancer mammograms breast) OR (cancer breast common occurrence mammograms) OR (disease cancer breast common mammograms) OR (disease among cancer common breast mammograms) OR (mammograms disease cancer breast common spread) OR (also cancer mammograms breast spreading) OR (product cancer mammograms breast)',
#  '(canal procedures cancer cause root) OR (surgery canal root cancers linked) OR (canal root cancer result surgery) OR (therapy result canal root cancer) OR (result canal root cancer surgeries) OR (surgery canal root cancer caused) OR (treatments result canal root cancer) OR (result canal root cancer treatment) OR (canal root cancer product surgery) OR (interventions canal root cancer result) OR (result canal root intervention cancer) OR (techniques result canal root cancer) OR (surgeries canal root cancer caused) OR (surgery canal root cancer linked) OR (surgery canal root cancer associated) OR (surgery canal root cancer related) OR (surgeries canal root cancer linked) OR (treatments canal root cancer caused) OR (techniques canal root cancer caused) OR (treatments canal root cancer linked) OR (therapy canal root cancer associated) OR (procedures canal root cancers linked) OR (therapy canal root cancer linked) OR (canal root common cancer surgery) OR (therapy canal root cancer caused)']

# %%
hoaxdf['final_lexical_enriched_query'] = lexically_enriched_final_query

# %%
hoaxdf.to_excel('/content/drive/MyDrive/working_directory/tfm/data/cancer_en_queries.xlsx', index=False)
